# %%
import pandas as pd

# 常量定义
TEAM_KEYWORDS = r'\b(Team|Relay|Doubles|Pairs|Crew|Squad|Group|Combined)\b'

def process_medal_data(input_file, output_file):
    # 数据读取与预处理
    df = pd.read_csv(input_file, keep_default_na=False)
    
    # 标记团体项目
    df['is_team'] = df['Event'].str.contains(
        TEAM_KEYWORDS, 
        case=False, 
        regex=True,
        na=False
    )
    
    # 处理团体项目去重
    team_dedup = df[df['is_team']].drop_duplicates(
        subset=['NOC', 'Year', 'Sport', 'Event'],
        keep='first'
    )
    
    # 合并数据
    final_df = pd.concat([
        df[~df['is_team']],
        team_dedup
    ], ignore_index=True)
    
    # 分组统计（核心改进）
    result = final_df.groupby(
        ['NOC', 'Year', 'Sport'],  # 按国家、年份、运动分组
        as_index=False             # 保留原始列作为字段
    ).agg({
        'Total': 'sum',           # 总奖牌数求和
        'Gold': 'sum',            # 金牌数求和
        'Silver': 'sum',          # 银牌数求和
        'Bronze': 'sum'           # 铜牌数求和
    })
    
    # 输出结果
    result.to_csv(output_file, index=False)
    print(f"处理完成，结果已保存至 {output_file}")

# 执行示例
process_medal_data(r"C:\Users\NANA\.jupyter\JupyterProject\MCM_02\code\data\athletes_1.csv", r"C:\Users\NANA\.jupyter\JupyterProject\MCM_02\olympic_medal_summary.csv")
# Out:
# C:\Users\NANA\AppData\Local\Temp\ipykernel_44392\3935887476.py:11: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df['is_team'] = df['Event'].str.contains(
# 处理完成，结果已保存至 C:\Users\NANA\.jupyter\JupyterProject\MCM_02\olympic_medal_summary.csv

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import STL
import warnings

# 禁用警告
warnings.filterwarnings("ignore")

def process_country_sport(group):
    """处理单个国家-运动组合"""
    try:
        noc = group['NOC'].iloc[0]
        sport = group['Sport'].iloc[0]
        
        # 生成完整奥运时间轴
        min_year = group['Year'].min()
        max_year = group['Year'].max()
        full_years = pd.Index(
            np.arange(min_year, max_year + 4, 4),
            name='Year'
        )
        
        # 创建完整时间序列
        full_df = pd.DataFrame({'Year': full_years})
        merged = pd.merge(full_df, group, on='Year', how='left')
        
        # 标记参赛情况并填充0值
        merged['participated'] = merged['Total'].notna()
        merged.fillna({'Total': 0, 'Gold': 0, 'Silver': 0, 'Bronze': 0}, inplace=True)
        merged[['Total', 'Gold', 'Silver', 'Bronze']] = merged[['Total', 'Gold', 'Silver', 'Bronze']].astype(int)
        
        # STL分解（针对总奖牌数）
        ts = merged.set_index('Year')['Total']
        res = STL(
            ts,
            period=4,       # 奥运周期
            seasonal=5,     # 5届季节性窗口
            trend=7,        # 7届趋势窗口
            robust=True
        ).fit()
        
        # 合并分解结果
        result = merged.copy()
        result['Trend'] = res.trend.values
        result['Seasonal'] = res.seasonal.values
        result['Residual'] = res.resid.values
        
        # 只保留原始参赛年份
        final = result[result['participated']].drop(columns=['participated'])
        final['NOC'] = noc
        final['Sport'] = sport
        
        return final[['NOC', 'Year', 'Sport', 'Total', 'Gold', 'Silver', 'Bronze', 'Trend', 'Seasonal', 'Residual']]
    
    except Exception as e:
        print(f"Error processing {noc}-{sport}: {str(e)}")
        return None

def main(input_file, output_file):
    # 读取数据（优化内存使用）
    df = pd.read_csv(
        input_file,
        dtype={
            'NOC': 'category',
            'Year': int,
            'Sport': 'category',
            'Total': 'int16',
            'Gold': 'int8',
            'Silver': 'int8',
            'Bronze': 'int8'
        }
    )
    
    # 单进程处理
    results = []
    for (noc, sport), group in df.groupby(['NOC', 'Sport']):
        if len(group) >= 3:  # 至少需要3个数据点
            result = process_country_sport(group)
            if result is not None:
                results.append(result)
                print(f"已处理 {noc}-{sport} ({len(group)}条数据)")
    
    # 合并结果
    if results:
        final_df = pd.concat(results, ignore_index=True)
        final_df.to_csv(output_file, index=False)
        print(f"处理完成！共处理{len(final_df)}条有效记录")
    else:
        print("未生成有效结果")

if __name__ == "__main__":
    # 使用示例路径
    input_path = r"C:\Users\NANA\.jupyter\JupyterProject\MCM_02\code\data\olympic_medal_summary.csv"
    output_path = r"C:\Users\NANA\.jupyter\JupyterProject\MCM_02\decomposition_results.csv"
    
    # 执行主程序
    main(input_path, output_path)
# Out:
# 已处理 AFG-Athletics (9条数据)
# 已处理 AFG-Boxing (3条数据)
# 已处理 AFG-Hockey (3条数据)
# 已处理 AFG-Judo (4条数据)
# 已处理 AFG-Taekwondo (3条数据)
# 已处理 AFG-Wrestling (7条数据)
# 已处理 AHO-Athletics (7条数据)
# 已处理 AHO-Sailing (4条数据)
# 已处理 AHO-Shooting (6条数据)
# 已处理 AHO-Swimming (5条数据)
# 已处理 AHO-Weightlifting (4条数据)
# 已处理 ALB-Athletics (9条数据)
# 已处理 ALB-Judo (3条数据)
# 已处理 ALB-Shooting (8条数据)
# 已处理 ALB-Swimming (7条数据)
# 已处理 ALB-Weightlifting (9条数据)
# 已处理 ALB-Wrestling (4条数据)
# 已处理 ALG-Athletics (13条数据)
# 已处理 ALG-Boxing (14条数据)
# 已处理 ALG-Cycling (4条数据)
# 已处理 ALG-Fencing (9条数据)
# 已处理 ALG-Gymnastics (3条数据)
# 已处理 ALG-Handball (4条数据)
# 已处理 ALG-Judo (11条数据)
# 已处理 ALG-Rowing (8条数据)
# 已处理 ALG-Sailing (3条数据)
# 已处理 ALG-Shooting (4条数据)
# 已处理 ALG-Swimming (10条数据)
# 已处理 ALG-Table Tennis (5条数据)
# 已处理 ALG-Volleyball (3条数据)
# 已处理 ALG-Weightlifting (12条数据)
# 已处理 ALG-Wrestling (10条数据)
# 已处理 AND-Athletics (10条数据)
# 已处理 AND-Judo (6条数据)
# 已处理 AND-Shooting (9条数据)
# 已处理 AND-Swimming (6条数据)
# 已处理 ANG-Athletics (11条数据)
# 已处理 ANG-Basketball (6条数据)
# 已处理 ANG-Boxing (3条数据)
# 已处理 ANG-Handball (8条数据)
# 已处理 ANG-Judo (7条数据)
# 已处理 ANG-Sailing (4条数据)
# 已处理 ANG-Shooting (3条数据)
# 已处理 ANG-Swimming (11条数据)
# 已处理 ANT-Athletics (12条数据)
# 已处理 ANT-Cycling (5条数据)
# 已处理 ANT-Sailing (7条数据)
# 已处理 ANT-Swimming (6条数据)
# 已处理 ARG-Athletics (23条数据)
# 已处理 ARG-Basketball (8条数据)
# 已处理 ARG-Beach Volleyball (7条数据)
# 已处理 ARG-Boxing (23条数据)
# 已处理 ARG-Canoeing (9条数据)
# 已处理 ARG-Cycling (18条数据)
# 已处理 ARG-Diving (5条数据)
# 已处理 ARG-Equestrianism (16条数据)
# 已处理 ARG-Fencing (24条数据)
# 已处理 ARG-Football (10条数据)
# 已处理 ARG-Golf (3条数据)
# 已处理 ARG-Gymnastics (10条数据)
# 已处理 ARG-Handball (4条数据)
# 已处理 ARG-Hockey (14条数据)
# 已处理 ARG-Judo (14条数据)
# 已处理 ARG-Modern Pentathlon (7条数据)
# 已处理 ARG-Rowing (21条数据)
# 已处理 ARG-Rugby Sevens (3条数据)
# 已处理 ARG-Sailing (22条数据)
# 已处理 ARG-Shooting (22条数据)
# 已处理 ARG-Swimming (22条数据)
# 已处理 ARG-Table Tennis (8条数据)
# 已处理 ARG-Taekwondo (6条数据)
# 已处理 ARG-Tennis (11条数据)
# 已处理 ARG-Triathlon (6条数据)
# 已处理 ARG-Volleyball (9条数据)
# 已处理 ARG-Water Polo (4条数据)
# 已处理 ARG-Weightlifting (14条数据)
# 已处理 ARG-Wrestling (16条数据)
# 已处理 ARM-Athletics (8条数据)
# 已处理 ARM-Boxing (8条数据)
# 已处理 ARM-Gymnastics (3条数据)
# 已处理 ARM-Judo (7条数据)
# 已处理 ARM-Shooting (8条数据)
# 已处理 ARM-Swimming (8条数据)
# 已处理 ARM-Tennis (3条数据)
# 已处理 ARM-Weightlifting (8条数据)
# 已处理 ARM-Wrestling (8条数据)
# 已处理 ARU-Athletics (5条数据)
# 已处理 ARU-Judo (5条数据)
# 已处理 ARU-Sailing (3条数据)
# 已处理 ARU-Swimming (7条数据)
# 已处理 ARU-Weightlifting (3条数据)
# 已处理 ASA-Athletics (9条数据)
# 已处理 ASA-Boxing (3条数据)
# 已处理 ASA-Judo (3条数据)
# 已处理 ASA-Swimming (4条数据)
# 已处理 ASA-Weightlifting (7条数据)
# 已处理 AUS-Archery (14条数据)
# 已处理 AUS-Athletics (29条数据)
# 已处理 AUS-Badminton (9条数据)
# 已处理 AUS-Baseball (3条数据)
# 已处理 AUS-Basketball (16条数据)
# 已处理 AUS-Beach Volleyball (8条数据)
# 已处理 AUS-Boxing (22条数据)
# 已处理 AUS-Canoeing (16条数据)
# 已处理 AUS-Cycling (23条数据)
# 已处理 AUS-Diving (24条数据)
# 已处理 AUS-Equestrianism (15条数据)
# 已处理 AUS-Fencing (15条数据)
# 已处理 AUS-Football (10条数据)
# 已处理 AUS-Golf (3条数据)
# 已处理 AUS-Gymnastics (16条数据)
# 已处理 AUS-Hockey (17条数据)
# 已处理 AUS-Judo (15条数据)
# 已处理 AUS-Modern Pentathlon (19条数据)
# 已处理 AUS-Rhythmic Gymnastics (8条数据)
# 已处理 AUS-Rowing (24条数据)
# 已处理 AUS-Rugby Sevens (3条数据)
# 已处理 AUS-Sailing (19条数据)
# 已处理 AUS-Shooting (19条数据)
# 已处理 AUS-Softball (4条数据)
# 已处理 AUS-Swimming (28条数据)
# 已处理 AUS-Synchronized Swimming (8条数据)
# 已处理 AUS-Table Tennis (10条数据)
# 已处理 AUS-Taekwondo (7条数据)
# 已处理 AUS-Tennis (13条数据)
# 已处理 AUS-Trampolining (5条数据)
# 已处理 AUS-Triathlon (7条数据)
# 已处理 AUS-Volleyball (3条数据)
# 已处理 AUS-Water Polo (18条数据)
# 已处理 AUS-Weightlifting (20条数据)
# 已处理 AUS-Wrestling (23条数据)
# 已处理 AUT-Archery (5条数据)
# 已处理 AUT-Art Competitions (4条数据)
# 已处理 AUT-Athletics (28条数据)
# 已处理 AUT-Badminton (6条数据)
# 已处理 AUT-Beach Volleyball (6条数据)
# 已处理 AUT-Boxing (14条数据)
# 已处理 AUT-Canoeing (18条数据)
# 已处理 AUT-Cycling (21条数据)
# 已处理 AUT-Diving (24条数据)
# 已处理 AUT-Equestrianism (19条数据)
# 已处理 AUT-Fencing (26条数据)
# 已处理 AUT-Football (4条数据)
# 已处理 AUT-Golf (3条数据)
# 已处理 AUT-Gymnastics (9条数据)
# 已处理 AUT-Handball (4条数据)
# 已处理 AUT-Hockey (4条数据)
# 已处理 AUT-Judo (15条数据)
# 已处理 AUT-Modern Pentathlon (11条数据)
# 已处理 AUT-Rhythmic Gymnastics (5条数据)
# 已处理 AUT-Rowing (21条数据)
# 已处理 AUT-Sailing (23条数据)
# 已处理 AUT-Shooting (23条数据)
# 已处理 AUT-Swimming (27条数据)
# 已处理 AUT-Synchronized Swimming (5条数据)
# 已处理 AUT-Table Tennis (10条数据)
# 已处理 AUT-Taekwondo (3条数据)
# 已处理 AUT-Tennis (12条数据)
# 已处理 AUT-Triathlon (7条数据)
# 已处理 AUT-Water Polo (3条数据)
# 已处理 AUT-Weightlifting (19条数据)
# 已处理 AUT-Wrestling (21条数据)
# 已处理 AZE-Athletics (8条数据)
# 已处理 AZE-Boxing (8条数据)
# 已处理 AZE-Fencing (6条数据)
# 已处理 AZE-Judo (8条数据)
# 已处理 AZE-Rhythmic Gymnastics (6条数据)
# 已处理 AZE-Rowing (3条数据)
# 已处理 AZE-Shooting (8条数据)
# 已处理 AZE-Swimming (8条数据)
# 已处理 AZE-Taekwondo (6条数据)
# 已处理 AZE-Triathlon (3条数据)
# 已处理 AZE-Weightlifting (5条数据)
# 已处理 AZE-Wrestling (8条数据)
# 已处理 BAH-Athletics (17条数据)
# 已处理 BAH-Boxing (4条数据)
# 已处理 BAH-Sailing (11条数据)
# 已处理 BAH-Swimming (12条数据)
# 已处理 BAH-Tennis (5条数据)
# 已处理 BAN-Archery (4条数据)
# 已处理 BAN-Athletics (11条数据)
# 已处理 BAN-Shooting (9条数据)
# 已处理 BAN-Swimming (10条数据)
# 已处理 BAR-Athletics (14条数据)
# 已处理 BAR-Boxing (5条数据)
# 已处理 BAR-Cycling (7条数据)
# 已处理 BAR-Judo (5条数据)
# 已处理 BAR-Sailing (6条数据)
# 已处理 BAR-Shooting (7条数据)
# 已处理 BAR-Swimming (11条数据)
# 已处理 BDI-Athletics (8条数据)
# 已处理 BDI-Judo (3条数据)
# 已处理 BDI-Swimming (6条数据)
# 已处理 BEL-Archery (12条数据)
# 已处理 BEL-Art Competitions (7条数据)
# 已处理 BEL-Athletics (27条数据)
# 已处理 BEL-Badminton (6条数据)
# 已处理 BEL-Basketball (5条数据)
# 已处理 BEL-Boxing (11条数据)
# 已处理 BEL-Canoeing (19条数据)
# 已处理 BEL-Cycling (26条数据)
# 已处理 BEL-Diving (6条数据)
# 已处理 BEL-Equestrianism (19条数据)
# 已处理 BEL-Fencing (23条数据)
# 已处理 BEL-Football (5条数据)
# 已处理 BEL-Golf (3条数据)
# 已处理 BEL-Gymnastics (16条数据)
# 已处理 BEL-Hockey (16条数据)
# 已处理 BEL-Judo (14条数据)
# 已处理 BEL-Modern Pentathlon (6条数据)
# 已处理 BEL-Rhythmic Gymnastics (4条数据)
# 已处理 BEL-Rowing (27条数据)
# 已处理 BEL-Sailing (23条数据)
# 已处理 BEL-Shooting (24条数据)
# 已处理 BEL-Swimming (25条数据)
# 已处理 BEL-Table Tennis (8条数据)
# 已处理 BEL-Taekwondo (4条数据)
# 已处理 BEL-Tennis (11条数据)
# 已处理 BEL-Triathlon (7条数据)
# 已处理 BEL-Water Polo (11条数据)
# 已处理 BEL-Weightlifting (19条数据)
# 已处理 BEL-Wrestling (19条数据)
# 已处理 BEN-Athletics (12条数据)
# 已处理 BEN-Boxing (4条数据)
# 已处理 BEN-Judo (5条数据)
# 已处理 BEN-Swimming (6条数据)
# 已处理 BER-Athletics (14条数据)
# 已处理 BER-Boxing (3条数据)
# 已处理 BER-Diving (3条数据)
# 已处理 BER-Equestrianism (8条数据)
# 已处理 BER-Rowing (4条数据)
# 已处理 BER-Sailing (15条数据)
# 已处理 BER-Swimming (12条数据)
# 已处理 BER-Triathlon (6条数据)
# 已处理 BHU-Archery (11条数据)
# 已处理 BHU-Shooting (3条数据)
# 已处理 BIH-Athletics (9条数据)
# 已处理 BIH-Canoeing (3条数据)
# 已处理 BIH-Judo (9条数据)
# 已处理 BIH-Shooting (8条数据)
# 已处理 BIH-Swimming (9条数据)
# 已处理 BIZ-Athletics (13条数据)
# 已处理 BIZ-Cycling (5条数据)
# 已处理 BIZ-Shooting (3条数据)
# 已处理 BLR-Archery (7条数据)
# 已处理 BLR-Athletics (7条数据)
# 已处理 BLR-Badminton (3条数据)
# 已处理 BLR-Boxing (7条数据)
# 已处理 BLR-Canoeing (6条数据)
# 已处理 BLR-Cycling (5条数据)
# 已处理 BLR-Diving (6条数据)
# 已处理 BLR-Equestrianism (3条数据)
# 已处理 BLR-Fencing (6条数据)
# 已处理 BLR-Gymnastics (6条数据)
# 已处理 BLR-Judo (7条数据)
# 已处理 BLR-Modern Pentathlon (6条数据)
# 已处理 BLR-Rhythmic Gymnastics (7条数据)
# 已处理 BLR-Rowing (7条数据)
# 已处理 BLR-Sailing (7条数据)
# 已处理 BLR-Shooting (7条数据)
# 已处理 BLR-Swimming (7条数据)
# 已处理 BLR-Synchronized Swimming (4条数据)
# 已处理 BLR-Table Tennis (6条数据)
# 已处理 BLR-Tennis (7条数据)
# 已处理 BLR-Trampolining (5条数据)
# 已处理 BLR-Weightlifting (7条数据)
# 已处理 BLR-Wrestling (7条数据)
# 已处理 BOH-Athletics (4条数据)
# 已处理 BOH-Fencing (3条数据)
# 已处理 BOH-Gymnastics (4条数据)
# 已处理 BOH-Tennis (4条数据)
# 已处理 BOH-Wrestling (3条数据)
# 已处理 BOL-Athletics (13条数据)
# 已处理 BOL-Cycling (6条数据)
# 已处理 BOL-Equestrianism (3条数据)
# 已处理 BOL-Fencing (3条数据)
# 已处理 BOL-Judo (5条数据)
# 已处理 BOL-Shooting (9条数据)
# 已处理 BOL-Swimming (11条数据)
# 已处理 BOL-Weightlifting (3条数据)
# 已处理 BOT-Athletics (12条数据)
# 已处理 BOT-Boxing (8条数据)
# 已处理 BOT-Swimming (4条数据)
# 已处理 BRA-Archery (9条数据)
# 已处理 BRA-Athletics (24条数据)
# 已处理 BRA-Badminton (3条数据)
# 已处理 BRA-Basketball (19条数据)
# 已处理 BRA-Beach Volleyball (8条数据)
# 已处理 BRA-Boxing (19条数据)
# 已处理 BRA-Canoeing (7条数据)
# 已处理 BRA-Cycling (14条数据)
# 已处理 BRA-Diving (17条数据)
# 已处理 BRA-Equestrianism (16条数据)
# 已处理 BRA-Fencing (14条数据)
# 已处理 BRA-Football (16条数据)
# 已处理 BRA-Gymnastics (9条数据)
# 已处理 BRA-Handball (9条数据)
# 已处理 BRA-Judo (15条数据)
# 已处理 BRA-Modern Pentathlon (12条数据)
# 已处理 BRA-Rhythmic Gymnastics (8条数据)
# 已处理 BRA-Rowing (23条数据)
# 已处理 BRA-Rugby Sevens (3条数据)
# 已处理 BRA-Sailing (21条数据)
# 已处理 BRA-Shooting (22条数据)
# 已处理 BRA-Swimming (23条数据)
# 已处理 BRA-Synchronized Swimming (8条数据)
# 已处理 BRA-Table Tennis (10条数据)
# 已处理 BRA-Taekwondo (7条数据)
# 已处理 BRA-Tennis (10条数据)
# 已处理 BRA-Triathlon (7条数据)
# 已处理 BRA-Volleyball (16条数据)
# 已处理 BRA-Water Polo (8条数据)
# 已处理 BRA-Weightlifting (16条数据)
# 已处理 BRA-Wrestling (8条数据)
# 已处理 BRN-Athletics (11条数据)
# 已处理 BRN-Shooting (6条数据)
# 已处理 BRN-Swimming (8条数据)
# 已处理 BRU-Athletics (6条数据)
# 已处理 BRU-Swimming (3条数据)
# 已处理 BUL-Archery (6条数据)
# 已处理 BUL-Athletics (19条数据)
# 已处理 BUL-Badminton (9条数据)
# 已处理 BUL-Basketball (7条数据)
# 已处理 BUL-Boxing (18条数据)
# 已处理 BUL-Canoeing (14条数据)
# 已处理 BUL-Cycling (13条数据)
# 已处理 BUL-Diving (3条数据)
# 已处理 BUL-Equestrianism (11条数据)
# 已处理 BUL-Fencing (11条数据)
# 已处理 BUL-Football (5条数据)
# 已处理 BUL-Gymnastics (16条数据)
# 已处理 BUL-Judo (11条数据)
# 已处理 BUL-Modern Pentathlon (8条数据)
# 已处理 BUL-Rhythmic Gymnastics (10条数据)
# 已处理 BUL-Rowing (12条数据)
# 已处理 BUL-Sailing (5条数据)
# 已处理 BUL-Shooting (18条数据)
# 已处理 BUL-Swimming (14条数据)
# 已处理 BUL-Table Tennis (3条数据)
# 已处理 BUL-Tennis (8条数据)
# 已处理 BUL-Volleyball (8条数据)
# 已处理 BUL-Weightlifting (15条数据)
# 已处理 BUL-Wrestling (17条数据)
# 已处理 BUR-Athletics (11条数据)
# 已处理 BUR-Boxing (3条数据)
# 已处理 BUR-Judo (8条数据)
# 已处理 BUR-Swimming (6条数据)
# 已处理 CAF-Athletics (12条数据)
# 已处理 CAF-Boxing (4条数据)
# 已处理 CAF-Judo (3条数据)
# 已处理 CAF-Swimming (4条数据)
# 已处理 CAF-Taekwondo (3条数据)
# 已处理 CAM-Athletics (9条数据)
# 已处理 CAM-Swimming (9条数据)
# 已处理 CAN-Archery (13条数据)
# 已处理 CAN-Art Competitions (5条数据)
# 已处理 CAN-Athletics (29条数据)
# 已处理 CAN-Badminton (9条数据)
# 已处理 CAN-Basketball (14条数据)
# 已处理 CAN-Beach Volleyball (7条数据)
# 已处理 CAN-Boxing (24条数据)
# 已处理 CAN-Canoeing (18条数据)
# 已处理 CAN-Cycling (23条数据)
# 已处理 CAN-Diving (24条数据)
# 已处理 CAN-Equestrianism (16条数据)
# 已处理 CAN-Fencing (22条数据)
# 已处理 CAN-Football (8条数据)
# 已处理 CAN-Golf (4条数据)
# 已处理 CAN-Gymnastics (16条数据)
# 已处理 CAN-Hockey (9条数据)
# 已处理 CAN-Judo (14条数据)
# 已处理 CAN-Modern Pentathlon (8条数据)
# 已处理 CAN-Rhythmic Gymnastics (7条数据)
# 已处理 CAN-Rowing (27条数据)
# 已处理 CAN-Rugby Sevens (3条数据)
# 已处理 CAN-Sailing (22条数据)
# 已处理 CAN-Shooting (22条数据)
# 已处理 CAN-Softball (4条数据)
# 已处理 CAN-Swimming (26条数据)
# 已处理 CAN-Synchronized Swimming (9条数据)
# 已处理 CAN-Table Tennis (10条数据)
# 已处理 CAN-Taekwondo (7条数据)
# 已处理 CAN-Tennis (11条数据)
# 已处理 CAN-Trampolining (5条数据)
# 已处理 CAN-Triathlon (7条数据)
# 已处理 CAN-Volleyball (7条数据)
# 已处理 CAN-Water Polo (8条数据)
# 已处理 CAN-Weightlifting (19条数据)
# 已处理 CAN-Wrestling (26条数据)
# 已处理 CAY-Athletics (10条数据)
# 已处理 CAY-Cycling (4条数据)
# 已处理 CAY-Sailing (7条数据)
# 已处理 CAY-Swimming (6条数据)
# 已处理 CGO-Athletics (14条数据)
# 已处理 CGO-Judo (5条数据)
# 已处理 CGO-Swimming (9条数据)
# 已处理 CGO-Table Tennis (4条数据)
# 已处理 CHA-Athletics (14条数据)
# 已处理 CHA-Judo (4条数据)
# 已处理 CHI-Archery (5条数据)
# 已处理 CHI-Athletics (24条数据)
# 已处理 CHI-Basketball (4条数据)
# 已处理 CHI-Beach Volleyball (3条数据)
# 已处理 CHI-Boxing (11条数据)
# 已处理 CHI-Cycling (16条数据)
# 已处理 CHI-Equestrianism (10条数据)
# 已处理 CHI-Fencing (13条数据)
# 已处理 CHI-Football (5条数据)
# 已处理 CHI-Golf (3条数据)
# 已处理 CHI-Judo (8条数据)
# 已处理 CHI-Modern Pentathlon (9条数据)
# 已处理 CHI-Rowing (12条数据)
# 已处理 CHI-Sailing (11条数据)
# 已处理 CHI-Shooting (21条数据)
# 已处理 CHI-Swimming (11条数据)
# 已处理 CHI-Table Tennis (8条数据)
# 已处理 CHI-Taekwondo (4条数据)
# 已处理 CHI-Tennis (9条数据)
# 已处理 CHI-Triathlon (6条数据)
# 已处理 CHI-Weightlifting (5条数据)
# 已处理 CHI-Wrestling (3条数据)
# 已处理 CHN-Archery (11条数据)
# 已处理 CHN-Athletics (14条数据)
# 已处理 CHN-Badminton (9条数据)
# 已处理 CHN-Basketball (13条数据)
# 已处理 CHN-Beach Volleyball (7条数据)
# 已处理 CHN-Boxing (11条数据)
# 已处理 CHN-Canoeing (8条数据)
# 已处理 CHN-Cycling (11条数据)
# 已处理 CHN-Diving (11条数据)
# 已处理 CHN-Fencing (11条数据)
# 已处理 CHN-Football (9条数据)
# 已处理 CHN-Golf (3条数据)
# 已处理 CHN-Gymnastics (9条数据)
# 已处理 CHN-Handball (5条数据)
# 已处理 CHN-Hockey (7条数据)
# 已处理 CHN-Judo (11条数据)
# 已处理 CHN-Modern Pentathlon (9条数据)
# 已处理 CHN-Rhythmic Gymnastics (11条数据)
# 已处理 CHN-Rowing (11条数据)
# 已处理 CHN-Sailing (11条数据)
# 已处理 CHN-Shooting (11条数据)
# 已处理 CHN-Softball (4条数据)
# 已处理 CHN-Swimming (14条数据)
# 已处理 CHN-Synchronized Swimming (8条数据)
# 已处理 CHN-Table Tennis (10条数据)
# 已处理 CHN-Taekwondo (7条数据)
# 已处理 CHN-Tennis (10条数据)
# 已处理 CHN-Trampolining (4条数据)
# 已处理 CHN-Triathlon (7条数据)
# 已处理 CHN-Volleyball (11条数据)
# 已处理 CHN-Water Polo (7条数据)
# 已处理 CHN-Weightlifting (12条数据)
# 已处理 CHN-Wrestling (11条数据)
# 已处理 CIV-Athletics (15条数据)
# 已处理 CIV-Boxing (3条数据)
# 已处理 CIV-Canoeing (7条数据)
# 已处理 CIV-Judo (8条数据)
# 已处理 CIV-Swimming (6条数据)
# 已处理 CIV-Taekwondo (7条数据)
# 已处理 CMR-Athletics (15条数据)
# 已处理 CMR-Boxing (12条数据)
# 已处理 CMR-Cycling (4条数据)
# 已处理 CMR-Football (4条数据)
# 已处理 CMR-Judo (10条数据)
# 已处理 CMR-Swimming (5条数据)
# 已处理 CMR-Table Tennis (4条数据)
# 已处理 CMR-Weightlifting (8条数据)
# 已处理 CMR-Wrestling (8条数据)
# 已处理 COD-Athletics (11条数据)
# 已处理 COD-Boxing (7条数据)
# 已处理 COD-Cycling (3条数据)
# 已处理 COD-Judo (6条数据)
# 已处理 COK-Athletics (10条数据)
# 已处理 COK-Sailing (4条数据)
# 已处理 COK-Swimming (5条数据)
# 已处理 COK-Weightlifting (7条数据)
# 已处理 COL-Archery (7条数据)
# 已处理 COL-Athletics (20条数据)
# 已处理 COL-Boxing (13条数据)
# 已处理 COL-Cycling (15条数据)
# 已处理 COL-Diving (11条数据)
# 已处理 COL-Equestrianism (8条数据)
# 已处理 COL-Fencing (13条数据)
# 已处理 COL-Football (7条数据)
# 已处理 COL-Golf (3条数据)
# 已处理 COL-Gymnastics (4条数据)
# 已处理 COL-Judo (7条数据)
# 已处理 COL-Sailing (5条数据)
# 已处理 COL-Shooting (15条数据)
# 已处理 COL-Swimming (18条数据)
# 已处理 COL-Table Tennis (3条数据)
# 已处理 COL-Taekwondo (6条数据)
# 已处理 COL-Tennis (6条数据)
# 已处理 COL-Triathlon (4条数据)
# 已处理 COL-Weightlifting (15条数据)
# 已处理 COL-Wrestling (11条数据)
# 已处理 COM-Athletics (8条数据)
# 已处理 COM-Swimming (4条数据)
# 已处理 CPV-Athletics (8条数据)
# 已处理 CPV-Boxing (4条数据)
# 已处理 CPV-Judo (3条数据)
# 已处理 CPV-Rhythmic Gymnastics (4条数据)
# 已处理 CRC-Archery (3条数据)
# 已处理 CRC-Athletics (12条数据)
# 已处理 CRC-Cycling (8条数据)
# 已处理 CRC-Football (3条数据)
# 已处理 CRC-Judo (11条数据)
# 已处理 CRC-Shooting (8条数据)
# 已处理 CRC-Swimming (14条数据)
# 已处理 CRC-Taekwondo (4条数据)
# 已处理 CRC-Triathlon (3条数据)
# 已处理 CRO-Athletics (9条数据)
# 已处理 CRO-Basketball (5条数据)
# 已处理 CRO-Boxing (7条数据)
# 已处理 CRO-Canoeing (6条数据)
# 已处理 CRO-Cycling (3条数据)
# 已处理 CRO-Gymnastics (4条数据)
# 已处理 CRO-Handball (6条数据)
# 已处理 CRO-Judo (4条数据)
# 已处理 CRO-Rowing (9条数据)
# 已处理 CRO-Sailing (9条数据)
# 已处理 CRO-Shooting (9条数据)
# 已处理 CRO-Swimming (8条数据)
# 已处理 CRO-Table Tennis (9条数据)
# 已处理 CRO-Taekwondo (7条数据)
# 已处理 CRO-Tennis (9条数据)
# 已处理 CRO-Water Polo (8条数据)
# 已处理 CRO-Weightlifting (3条数据)
# 已处理 CRO-Wrestling (5条数据)
# 已处理 CUB-Archery (6条数据)
# 已处理 CUB-Athletics (20条数据)
# 已处理 CUB-Baseball (5条数据)
# 已处理 CUB-Basketball (9条数据)
# 已处理 CUB-Beach Volleyball (7条数据)
# 已处理 CUB-Boxing (15条数据)
# 已处理 CUB-Canoeing (8条数据)
# 已处理 CUB-Cycling (12条数据)
# 已处理 CUB-Diving (8条数据)
# 已处理 CUB-Fencing (17条数据)
# 已处理 CUB-Gymnastics (12条数据)
# 已处理 CUB-Judo (12条数据)
# 已处理 CUB-Modern Pentathlon (4条数据)
# 已处理 CUB-Rowing (16条数据)
# 已处理 CUB-Sailing (8条数据)
# 已处理 CUB-Shooting (15条数据)
# 已处理 CUB-Swimming (14条数据)
# 已处理 CUB-Table Tennis (6条数据)
# 已处理 CUB-Taekwondo (7条数据)
# 已处理 CUB-Volleyball (9条数据)
# 已处理 CUB-Water Polo (5条数据)
# 已处理 CUB-Weightlifting (17条数据)
# 已处理 CUB-Wrestling (15条数据)
# 已处理 CYP-Athletics (11条数据)
# 已处理 CYP-Cycling (4条数据)
# 已处理 CYP-Judo (6条数据)
# 已处理 CYP-Rhythmic Gymnastics (3条数据)
# 已处理 CYP-Sailing (11条数据)
# 已处理 CYP-Shooting (11条数据)
# 已处理 CYP-Swimming (10条数据)
# 已处理 CZE-Archery (3条数据)
# 已处理 CZE-Athletics (8条数据)
# 已处理 CZE-Badminton (4条数据)
# 已处理 CZE-Basketball (4条数据)
# 已处理 CZE-Beach Volleyball (7条数据)
# 已处理 CZE-Boxing (3条数据)
# 已处理 CZE-Canoeing (6条数据)
# 已处理 CZE-Cycling (6条数据)
# 已处理 CZE-Fencing (4条数据)
# 已处理 CZE-Golf (3条数据)
# 已处理 CZE-Gymnastics (6条数据)
# 已处理 CZE-Judo (8条数据)
# 已处理 CZE-Modern Pentathlon (6条数据)
# 已处理 CZE-Rowing (8条数据)
# 已处理 CZE-Sailing (8条数据)
# 已处理 CZE-Shooting (8条数据)
# 已处理 CZE-Swimming (8条数据)
# 已处理 CZE-Synchronized Swimming (5条数据)
# 已处理 CZE-Table Tennis (8条数据)
# 已处理 CZE-Tennis (8条数据)
# 已处理 CZE-Trampolining (3条数据)
# 已处理 CZE-Triathlon (7条数据)
# 已处理 CZE-Weightlifting (8条数据)
# 已处理 CZE-Wrestling (7条数据)
# 已处理 DEN-Archery (10条数据)
# 已处理 DEN-Art Competitions (5条数据)
# 已处理 DEN-Athletics (30条数据)
# 已处理 DEN-Badminton (9条数据)
# 已处理 DEN-Boxing (20条数据)
# 已处理 DEN-Canoeing (19条数据)
# 已处理 DEN-Cycling (25条数据)
# 已处理 DEN-Diving (11条数据)
# 已处理 DEN-Equestrianism (19条数据)
# 已处理 DEN-Fencing (18条数据)
# 已处理 DEN-Football (11条数据)
# 已处理 DEN-Golf (3条数据)
# 已处理 DEN-Gymnastics (10条数据)
# 已处理 DEN-Handball (12条数据)
# 已处理 DEN-Hockey (5条数据)
# 已处理 DEN-Judo (4条数据)
# 已处理 DEN-Modern Pentathlon (10条数据)
# 已处理 DEN-Rowing (25条数据)
# 已处理 DEN-Sailing (24条数据)
# 已处理 DEN-Shooting (27条数据)
# 已处理 DEN-Swimming (28条数据)
# 已处理 DEN-Table Tennis (7条数据)
# 已处理 DEN-Taekwondo (3条数据)
# 已处理 DEN-Tennis (11条数据)
# 已处理 DEN-Trampolining (3条数据)
# 已处理 DEN-Triathlon (6条数据)
# 已处理 DEN-Weightlifting (12条数据)
# 已处理 DEN-Wrestling (21条数据)
# 已处理 DJI-Athletics (10条数据)
# 已处理 DJI-Judo (4条数据)
# 已处理 DJI-Sailing (3条数据)
# 已处理 DJI-Swimming (4条数据)
# 已处理 DMA-Athletics (8条数据)
# 已处理 DMA-Swimming (3条数据)
# 已处理 DOM-Athletics (14条数据)
# 已处理 DOM-Boxing (14条数据)
# 已处理 DOM-Diving (4条数据)
# 已处理 DOM-Judo (12条数据)
# 已处理 DOM-Shooting (7条数据)
# 已处理 DOM-Swimming (6条数据)
# 已处理 DOM-Table Tennis (5条数据)
# 已处理 DOM-Taekwondo (6条数据)
# 已处理 DOM-Volleyball (4条数据)
# 已处理 DOM-Weightlifting (14条数据)
# 已处理 DOM-Wrestling (6条数据)
# 已处理 ECU-Athletics (14条数据)
# 已处理 ECU-Boxing (11条数据)
# 已处理 ECU-Cycling (8条数据)
# 已处理 ECU-Equestrianism (3条数据)
# 已处理 ECU-Judo (11条数据)
# 已处理 ECU-Shooting (11条数据)
# 已处理 ECU-Swimming (13条数据)
# 已处理 ECU-Table Tennis (3条数据)
# 已处理 ECU-Tennis (3条数据)
# 已处理 ECU-Triathlon (4条数据)
# 已处理 ECU-Weightlifting (9条数据)
# 已处理 ECU-Wrestling (7条数据)
# 已处理 EGY-Archery (7条数据)
# 已处理 EGY-Athletics (16条数据)
# 已处理 EGY-Badminton (3条数据)
# 已处理 EGY-Basketball (7条数据)
# 已处理 EGY-Boxing (19条数据)
# 已处理 EGY-Cycling (4条数据)
# 已处理 EGY-Diving (9条数据)
# 已处理 EGY-Equestrianism (9条数据)
# 已处理 EGY-Fencing (18条数据)
# 已处理 EGY-Football (12条数据)
# 已处理 EGY-Gymnastics (8条数据)
# 已处理 EGY-Handball (8条数据)
# 已处理 EGY-Judo (11条数据)
# 已处理 EGY-Modern Pentathlon (10条数据)
# 已处理 EGY-Rhythmic Gymnastics (4条数据)
# 已处理 EGY-Rowing (11条数据)
# 已处理 EGY-Sailing (5条数据)
# 已处理 EGY-Shooting (16条数据)
# 已处理 EGY-Swimming (15条数据)
# 已处理 EGY-Synchronized Swimming (6条数据)
# 已处理 EGY-Table Tennis (8条数据)
# 已处理 EGY-Taekwondo (7条数据)
# 已处理 EGY-Volleyball (6条数据)
# 已处理 EGY-Water Polo (5条数据)
# 已处理 EGY-Weightlifting (19条数据)
# 已处理 EGY-Wrestling (21条数据)
# 已处理 ERI-Athletics (7条数据)
# 已处理 ESA-Archery (3条数据)
# 已处理 ESA-Athletics (11条数据)
# 已处理 ESA-Cycling (6条数据)
# 已处理 ESA-Judo (9条数据)
# 已处理 ESA-Sailing (4条数据)
# 已处理 ESA-Shooting (9条数据)
# 已处理 ESA-Swimming (12条数据)
# 已处理 ESA-Weightlifting (7条数据)
# 已处理 ESA-Wrestling (3条数据)
# 已处理 ESP-Archery (13条数据)
# 已处理 ESP-Art Competitions (3条数据)
# 已处理 ESP-Athletics (21条数据)
# 已处理 ESP-Badminton (7条数据)
# 已处理 ESP-Basketball (14条数据)
# 已处理 ESP-Beach Volleyball (8条数据)
# 已处理 ESP-Boxing (18条数据)
# 已处理 ESP-Canoeing (14条数据)
# 已处理 ESP-Cycling (15条数据)
# 已处理 ESP-Diving (14条数据)
# 已处理 ESP-Equestrianism (19条数据)
# 已处理 ESP-Fencing (14条数据)
# 已处理 ESP-Football (12条数据)
# 已处理 ESP-Golf (3条数据)
# 已处理 ESP-Gymnastics (14条数据)
# 已处理 ESP-Handball (13条数据)
# 已处理 ESP-Hockey (19条数据)
# 已处理 ESP-Judo (14条数据)
# 已处理 ESP-Modern Pentathlon (9条数据)
# 已处理 ESP-Rhythmic Gymnastics (10条数据)
# 已处理 ESP-Rowing (17条数据)
# 已处理 ESP-Sailing (22条数据)
# 已处理 ESP-Shooting (22条数据)
# 已处理 ESP-Swimming (22条数据)
# 已处理 ESP-Synchronized Swimming (8条数据)
# 已处理 ESP-Table Tennis (7条数据)
# 已处理 ESP-Taekwondo (7条数据)
# 已处理 ESP-Tennis (12条数据)
# 已处理 ESP-Triathlon (7条数据)
# 已处理 ESP-Water Polo (19条数据)
# 已处理 ESP-Weightlifting (13条数据)
# 已处理 ESP-Wrestling (11条数据)
# 已处理 EST-Archery (6条数据)
# 已处理 EST-Athletics (14条数据)
# 已处理 EST-Badminton (5条数据)
# 已处理 EST-Boxing (3条数据)
# 已处理 EST-Canoeing (3条数据)
# 已处理 EST-Cycling (7条数据)
# 已处理 EST-Fencing (8条数据)
# 已处理 EST-Judo (9条数据)
# 已处理 EST-Modern Pentathlon (3条数据)
# 已处理 EST-Rowing (10条数据)
# 已处理 EST-Sailing (11条数据)
# 已处理 EST-Shooting (9条数据)
# 已处理 EST-Swimming (10条数据)
# 已处理 EST-Tennis (3条数据)
# 已处理 EST-Triathlon (4条数据)
# 已处理 EST-Weightlifting (6条数据)
# 已处理 EST-Wrestling (13条数据)
# 已处理 ETH-Athletics (15条数据)
# 已处理 ETH-Boxing (7条数据)
# 已处理 ETH-Cycling (8条数据)
# 已处理 ETH-Swimming (4条数据)
# 已处理 FIJ-Archery (3条数据)
# 已处理 FIJ-Athletics (16条数据)
# 已处理 FIJ-Boxing (3条数据)
# 已处理 FIJ-Judo (11条数据)
# 已处理 FIJ-Rugby Sevens (3条数据)
# 已处理 FIJ-Sailing (8条数据)
# 已处理 FIJ-Shooting (4条数据)
# 已处理 FIJ-Swimming (11条数据)
# 已处理 FIJ-Table Tennis (3条数据)
# 已处理 FIJ-Weightlifting (6条数据)
# 已处理 FIN-Archery (13条数据)
# 已处理 FIN-Art Competitions (3条数据)
# 已处理 FIN-Athletics (28条数据)
# 已处理 FIN-Badminton (9条数据)
# 已处理 FIN-Boxing (19条数据)
# 已处理 FIN-Canoeing (18条数据)
# 已处理 FIN-Cycling (19条数据)
# 已处理 FIN-Diving (18条数据)
# 已处理 FIN-Equestrianism (16条数据)
# 已处理 FIN-Fencing (10条数据)
# 已处理 FIN-Football (4条数据)
# 已处理 FIN-Golf (3条数据)
# 已处理 FIN-Gymnastics (15条数据)
# 已处理 FIN-Judo (13条数据)
# 已处理 FIN-Modern Pentathlon (14条数据)
# 已处理 FIN-Rhythmic Gymnastics (4条数据)
# 已处理 FIN-Rowing (15条数据)
# 已处理 FIN-Sailing (24条数据)
# 已处理 FIN-Shooting (25条数据)
# 已处理 FIN-Swimming (27条数据)
# 已处理 FIN-Taekwondo (4条数据)
# 已处理 FIN-Tennis (4条数据)
# 已处理 FIN-Weightlifting (18条数据)
# 已处理 FIN-Wrestling (28条数据)
# 已处理 FRA-Archery (16条数据)
# 已处理 FRA-Art Competitions (6条数据)
# 已处理 FRA-Athletics (31条数据)
# 已处理 FRA-Badminton (9条数据)
# 已处理 FRA-Basketball (11条数据)
# 已处理 FRA-Beach Volleyball (4条数据)
# 已处理 FRA-Boxing (26条数据)
# 已处理 FRA-Canoeing (19条数据)
# 已处理 FRA-Cycling (28条数据)
# 已处理 FRA-Diving (23条数据)
# 已处理 FRA-Equestrianism (24条数据)
# 已处理 FRA-Fencing (29条数据)
# 已处理 FRA-Football (17条数据)
# 已处理 FRA-Golf (4条数据)
# 已处理 FRA-Gymnastics (27条数据)
# 已处理 FRA-Handball (9条数据)
# 已处理 FRA-Hockey (10条数据)
# 已处理 FRA-Judo (15条数据)
# 已处理 FRA-Modern Pentathlon (25条数据)
# 已处理 FRA-Rhythmic Gymnastics (8条数据)
# 已处理 FRA-Rowing (28条数据)
# 已处理 FRA-Rugby (3条数据)
# 已处理 FRA-Rugby Sevens (3条数据)
# 已处理 FRA-Sailing (27条数据)
# 已处理 FRA-Shooting (27条数据)
# 已处理 FRA-Swimming (29条数据)
# 已处理 FRA-Synchronized Swimming (9条数据)
# 已处理 FRA-Table Tennis (10条数据)
# 已处理 FRA-Taekwondo (7条数据)
# 已处理 FRA-Tennis (17条数据)
# 已处理 FRA-Trampolining (5条数据)
# 已处理 FRA-Triathlon (7条数据)
# 已处理 FRA-Volleyball (6条数据)
# 已处理 FRA-Water Polo (12条数据)
# 已处理 FRA-Weightlifting (26条数据)
# 已处理 FRA-Wrestling (27条数据)
# 已处理 FRG-Archery (4条数据)
# 已处理 FRG-Athletics (5条数据)
# 已处理 FRG-Boxing (5条数据)
# 已处理 FRG-Canoeing (5条数据)
# 已处理 FRG-Cycling (5条数据)
# 已处理 FRG-Diving (5条数据)
# 已处理 FRG-Equestrianism (5条数据)
# 已处理 FRG-Fencing (5条数据)
# 已处理 FRG-Football (3条数据)
# 已处理 FRG-Gymnastics (5条数据)
# 已处理 FRG-Handball (3条数据)
# 已处理 FRG-Hockey (5条数据)
# 已处理 FRG-Judo (4条数据)
# 已处理 FRG-Modern Pentathlon (5条数据)
# 已处理 FRG-Rowing (5条数据)
# 已处理 FRG-Sailing (5条数据)
# 已处理 FRG-Shooting (5条数据)
# 已处理 FRG-Swimming (5条数据)
# 已处理 FRG-Water Polo (5条数据)
# 已处理 FRG-Weightlifting (5条数据)
# 已处理 FRG-Wrestling (5条数据)
# 已处理 FSM-Athletics (7条数据)
# 已处理 FSM-Swimming (7条数据)
# 已处理 FSM-Weightlifting (4条数据)
# 已处理 GAB-Athletics (11条数据)
# 已处理 GAB-Boxing (8条数据)
# 已处理 GAB-Judo (9条数据)
# 已处理 GAB-Swimming (3条数据)
# 已处理 GAB-Taekwondo (5条数据)
# 已处理 GAM-Athletics (11条数据)
# 已处理 GAM-Judo (3条数据)
# 已处理 GAM-Swimming (3条数据)
# 已处理 GBR-Archery (15条数据)
# 已处理 GBR-Art Competitions (6条数据)
# 已处理 GBR-Athletics (31条数据)
# 已处理 GBR-Badminton (9条数据)
# 已处理 GBR-Boxing (26条数据)
# 已处理 GBR-Canoeing (19条数据)
# 已处理 GBR-Cycling (28条数据)
# 已处理 GBR-Diving (27条数据)
# 已处理 GBR-Equestrianism (21条数据)
# 已处理 GBR-Fencing (29条数据)
# 已处理 GBR-Football (12条数据)
# 已处理 GBR-Golf (5条数据)
# 已处理 GBR-Gymnastics (27条数据)
# 已处理 GBR-Hockey (20条数据)
# 已处理 GBR-Judo (15条数据)
# 已处理 GBR-Modern Pentathlon (26条数据)
# 已处理 GBR-Polo (5条数据)
# 已处理 GBR-Rhythmic Gymnastics (5条数据)
# 已处理 GBR-Rowing (29条数据)
# 已处理 GBR-Rugby Sevens (3条数据)
# 已处理 GBR-Sailing (26条数据)
# 已处理 GBR-Shooting (26条数据)
# 已处理 GBR-Swimming (29条数据)
# 已处理 GBR-Synchronized Swimming (6条数据)
# 已处理 GBR-Table Tennis (8条数据)
# 已处理 GBR-Taekwondo (7条数据)
# 已处理 GBR-Tennis (16条数据)
# 已处理 GBR-Trampolining (5条数据)
# 已处理 GBR-Triathlon (7条数据)
# 已处理 GBR-Tug-Of-War (3条数据)
# 已处理 GBR-Water Polo (11条数据)
# 已处理 GBR-Weightlifting (25条数据)
# 已处理 GBR-Wrestling (23条数据)
# 已处理 GBS-Athletics (8条数据)
# 已处理 GBS-Judo (3条数据)
# 已处理 GBS-Wrestling (8条数据)
# 已处理 GDR-Athletics (5条数据)
# 已处理 GDR-Boxing (5条数据)
# 已处理 GDR-Canoeing (5条数据)
# 已处理 GDR-Cycling (5条数据)
# 已处理 GDR-Diving (5条数据)
# 已处理 GDR-Fencing (5条数据)
# 已处理 GDR-Football (3条数据)
# 已处理 GDR-Gymnastics (5条数据)
# 已处理 GDR-Handball (4条数据)
# 已处理 GDR-Judo (4条数据)
# 已处理 GDR-Rowing (5条数据)
# 已处理 GDR-Sailing (5条数据)
# 已处理 GDR-Shooting (5条数据)
# 已处理 GDR-Swimming (5条数据)
# 已处理 GDR-Volleyball (5条数据)
# 已处理 GDR-Weightlifting (5条数据)
# 已处理 GDR-Wrestling (5条数据)
# 已处理 GEO-Archery (6条数据)
# 已处理 GEO-Athletics (8条数据)
# 已处理 GEO-Boxing (6条数据)
# 已处理 GEO-Fencing (4条数据)
# 已处理 GEO-Gymnastics (4条数据)
# 已处理 GEO-Judo (8条数据)
# 已处理 GEO-Rhythmic Gymnastics (4条数据)
# 已处理 GEO-Shooting (8条数据)
# 已处理 GEO-Swimming (7条数据)
# 已处理 GEO-Tennis (3条数据)
# 已处理 GEO-Trampolining (5条数据)
# 已处理 GEO-Weightlifting (8条数据)
# 已处理 GEO-Wrestling (8条数据)
# 已处理 GEQ-Athletics (11条数据)
# 已处理 GEQ-Swimming (3条数据)
# 已处理 GER-Archery (9条数据)
# 已处理 GER-Art Competitions (4条数据)
# 已处理 GER-Athletics (22条数据)
# 已处理 GER-Badminton (9条数据)
# 已处理 GER-Basketball (5条数据)
# 已处理 GER-Beach Volleyball (8条数据)
# 已处理 GER-Boxing (16条数据)
# 已处理 GER-Canoeing (12条数据)
# 已处理 GER-Cycling (19条数据)
# 已处理 GER-Diving (19条数据)
# 已处理 GER-Equestrianism (15条数据)
# 已处理 GER-Fencing (21条数据)
# 已处理 GER-Football (13条数据)
# 已处理 GER-Golf (3条数据)
# 已处理 GER-Gymnastics (18条数据)
# 已处理 GER-Handball (9条数据)
# 已处理 GER-Hockey (16条数据)
# 已处理 GER-Judo (10条数据)
# 已处理 GER-Modern Pentathlon (15条数据)
# 已处理 GER-Rhythmic Gymnastics (7条数据)
# 已处理 GER-Rowing (19条数据)
# 已处理 GER-Sailing (17条数据)
# 已处理 GER-Shooting (17条数据)
# 已处理 GER-Swimming (21条数据)
# 已处理 GER-Table Tennis (9条数据)
# 已处理 GER-Taekwondo (6条数据)
# 已处理 GER-Tennis (13条数据)
# 已处理 GER-Trampolining (5条数据)
# 已处理 GER-Triathlon (7条数据)
# 已处理 GER-Volleyball (6条数据)
# 已处理 GER-Water Polo (12条数据)
# 已处理 GER-Weightlifting (18条数据)
# 已处理 GER-Wrestling (21条数据)
# 已处理 GHA-Athletics (16条数据)
# 已处理 GHA-Boxing (13条数据)
# 已处理 GHA-Football (6条数据)
# 已处理 GHA-Judo (3条数据)
# 已处理 GHA-Swimming (3条数据)
# 已处理 GHA-Table Tennis (3条数据)
# 已处理 GHA-Weightlifting (3条数据)
# 已处理 GRE-Archery (6条数据)
# 已处理 GRE-Art Competitions (3条数据)
# 已处理 GRE-Athletics (31条数据)
# 已处理 GRE-Basketball (5条数据)
# 已处理 GRE-Beach Volleyball (4条数据)
# 已处理 GRE-Boxing (14条数据)
# 已处理 GRE-Canoeing (4条数据)
# 已处理 GRE-Cycling (13条数据)
# 已处理 GRE-Diving (7条数据)
# 已处理 GRE-Fencing (17条数据)
# 已处理 GRE-Football (4条数据)
# 已处理 GRE-Gymnastics (9条数据)
# 已处理 GRE-Judo (8条数据)
# 已处理 GRE-Modern Pentathlon (4条数据)
# 已处理 GRE-Rhythmic Gymnastics (8条数据)
# 已处理 GRE-Rowing (17条数据)
# 已处理 GRE-Sailing (20条数据)
# 已处理 GRE-Shooting (27条数据)
# 已处理 GRE-Swimming (21条数据)
# 已处理 GRE-Synchronized Swimming (6条数据)
# 已处理 GRE-Table Tennis (8条数据)
# 已处理 GRE-Taekwondo (5条数据)
# 已处理 GRE-Tennis (12条数据)
# 已处理 GRE-Triathlon (3条数据)
# 已处理 GRE-Water Polo (17条数据)
# 已处理 GRE-Weightlifting (19条数据)
# 已处理 GRE-Wrestling (28条数据)
# 已处理 GRN-Athletics (11条数据)
# 已处理 GRN-Boxing (3条数据)
# 已处理 GRN-Swimming (6条数据)
# 已处理 GUA-Athletics (13条数据)
# 已处理 GUA-Badminton (7条数据)
# 已处理 GUA-Boxing (5条数据)
# 已处理 GUA-Cycling (9条数据)
# 已处理 GUA-Equestrianism (4条数据)
# 已处理 GUA-Football (3条数据)
# 已处理 GUA-Gymnastics (4条数据)
# 已处理 GUA-Judo (6条数据)
# 已处理 GUA-Modern Pentathlon (7条数据)
# 已处理 GUA-Rowing (3条数据)
# 已处理 GUA-Sailing (9条数据)
# 已处理 GUA-Shooting (16条数据)
# 已处理 GUA-Swimming (13条数据)
# 已处理 GUA-Taekwondo (3条数据)
# 已处理 GUA-Weightlifting (12条数据)
# 已处理 GUA-Wrestling (6条数据)
# 已处理 GUI-Athletics (11条数据)
# 已处理 GUI-Boxing (4条数据)
# 已处理 GUI-Judo (9条数据)
# 已处理 GUI-Swimming (7条数据)
# 已处理 GUM-Athletics (10条数据)
# 已处理 GUM-Cycling (4条数据)
# 已处理 GUM-Judo (6条数据)
# 已处理 GUM-Sailing (4条数据)
# 已处理 GUM-Swimming (9条数据)
# 已处理 GUM-Weightlifting (4条数据)
# 已处理 GUM-Wrestling (8条数据)
# 已处理 GUY-Athletics (16条数据)
# 已处理 GUY-Boxing (9条数据)
# 已处理 GUY-Cycling (7条数据)
# 已处理 GUY-Swimming (6条数据)
# 已处理 GUY-Weightlifting (6条数据)
# 已处理 HAI-Athletics (16条数据)
# 已处理 HAI-Boxing (6条数据)
# 已处理 HAI-Judo (9条数据)
# 已处理 HAI-Swimming (4条数据)
# 已处理 HAI-Taekwondo (3条数据)
# 已处理 HAI-Tennis (3条数据)
# 已处理 HKG-Archery (4条数据)
# 已处理 HKG-Athletics (12条数据)
# 已处理 HKG-Badminton (9条数据)
# 已处理 HKG-Canoeing (4条数据)
# 已处理 HKG-Cycling (10条数据)
# 已处理 HKG-Diving (4条数据)
# 已处理 HKG-Fencing (11条数据)
# 已处理 HKG-Judo (8条数据)
# 已处理 HKG-Rowing (9条数据)
# 已处理 HKG-Sailing (14条数据)
# 已处理 HKG-Shooting (13条数据)
# 已处理 HKG-Swimming (18条数据)
# 已处理 HKG-Table Tennis (10条数据)
# 已处理 HKG-Triathlon (4条数据)
# 已处理 HON-Athletics (13条数据)
# 已处理 HON-Boxing (4条数据)
# 已处理 HON-Football (5条数据)
# 已处理 HON-Judo (6条数据)
# 已处理 HON-Swimming (11条数据)
# 已处理 HON-Taekwondo (3条数据)
# 已处理 HON-Weightlifting (3条数据)
# 已处理 HUN-Archery (5条数据)
# 已处理 HUN-Art Competitions (5条数据)
# 已处理 HUN-Athletics (29条数据)
# 已处理 HUN-Badminton (4条数据)
# 已处理 HUN-Basketball (5条数据)
# 已处理 HUN-Boxing (23条数据)
# 已处理 HUN-Canoeing (18条数据)
# 已处理 HUN-Cycling (19条数据)
# 已处理 HUN-Diving (14条数据)
# 已处理 HUN-Equestrianism (8条数据)
# 已处理 HUN-Fencing (27条数据)
# 已处理 HUN-Football (9条数据)
# 已处理 HUN-Gymnastics (25条数据)
# 已处理 HUN-Handball (13条数据)
# 已处理 HUN-Judo (13条数据)
# 已处理 HUN-Modern Pentathlon (22条数据)
# 已处理 HUN-Rhythmic Gymnastics (6条数据)
# 已处理 HUN-Rowing (23条数据)
# 已处理 HUN-Sailing (18条数据)
# 已处理 HUN-Shooting (25条数据)
# 已处理 HUN-Swimming (29条数据)
# 已处理 HUN-Table Tennis (10条数据)
# 已处理 HUN-Taekwondo (3条数据)
# 已处理 HUN-Tennis (14条数据)
# 已处理 HUN-Triathlon (7条数据)
# 已处理 HUN-Volleyball (4条数据)
# 已处理 HUN-Water Polo (24条数据)
# 已处理 HUN-Weightlifting (19条数据)
# 已处理 HUN-Wrestling (27条数据)
# 已处理 INA-Archery (13条数据)
# 已处理 INA-Athletics (15条数据)
# 已处理 INA-Badminton (9条数据)
# 已处理 INA-Boxing (9条数据)
# 已处理 INA-Cycling (4条数据)
# 已处理 INA-Fencing (5条数据)
# 已处理 INA-Judo (6条数据)
# 已处理 INA-Rowing (4条数据)
# 已处理 INA-Sailing (7条数据)
# 已处理 INA-Shooting (9条数据)
# 已处理 INA-Swimming (14条数据)
# 已处理 INA-Table Tennis (4条数据)
# 已处理 INA-Tennis (5条数据)
# 已处理 INA-Weightlifting (17条数据)
# 已处理 IND-Archery (9条数据)
# 已处理 IND-Athletics (26条数据)
# 已处理 IND-Badminton (9条数据)
# 已处理 IND-Boxing (16条数据)
# 已处理 IND-Cycling (3条数据)
# 已处理 IND-Equestrianism (3条数据)
# 已处理 IND-Football (4条数据)
# 已处理 IND-Golf (3条数据)
# 已处理 IND-Gymnastics (4条数据)
# 已处理 IND-Hockey (22条数据)
# 已处理 IND-Judo (9条数据)
# 已处理 IND-Rowing (7条数据)
# 已处理 IND-Sailing (8条数据)
# 已处理 IND-Shooting (19条数据)
# 已处理 IND-Swimming (13条数据)
# 已处理 IND-Table Tennis (10条数据)
# 已处理 IND-Tennis (11条数据)
# 已处理 IND-Weightlifting (20条数据)
# 已处理 IND-Wrestling (21条数据)
# 已处理 IOA-Athletics (3条数据)
# 已处理 IRI-Archery (5条数据)
# 已处理 IRI-Athletics (17条数据)
# 已处理 IRI-Basketball (3条数据)
# 已处理 IRI-Boxing (14条数据)
# 已处理 IRI-Canoeing (3条数据)
# 已处理 IRI-Cycling (10条数据)
# 已处理 IRI-Fencing (8条数据)
# 已处理 IRI-Football (3条数据)
# 已处理 IRI-Judo (5条数据)
# 已处理 IRI-Rowing (5条数据)
# 已处理 IRI-Shooting (11条数据)
# 已处理 IRI-Swimming (8条数据)
# 已处理 IRI-Table Tennis (8条数据)
# 已处理 IRI-Taekwondo (7条数据)
# 已处理 IRI-Weightlifting (16条数据)
# 已处理 IRI-Wrestling (18条数据)
# 已处理 IRL-Archery (6条数据)
# 已处理 IRL-Art Competitions (4条数据)
# 已处理 IRL-Athletics (23条数据)
# 已处理 IRL-Badminton (6条数据)
# 已处理 IRL-Boxing (23条数据)
# 已处理 IRL-Canoeing (11条数据)
# 已处理 IRL-Cycling (15条数据)
# 已处理 IRL-Diving (4条数据)
# 已处理 IRL-Equestrianism (17条数据)
# 已处理 IRL-Fencing (8条数据)
# 已处理 IRL-Golf (3条数据)
# 已处理 IRL-Gymnastics (3条数据)
# 已处理 IRL-Hockey (3条数据)
# 已处理 IRL-Judo (9条数据)
# 已处理 IRL-Modern Pentathlon (4条数据)
# 已处理 IRL-Rowing (14条数据)
# 已处理 IRL-Sailing (19条数据)
# 已处理 IRL-Shooting (11条数据)
# 已处理 IRL-Swimming (16条数据)
# 已处理 IRL-Tennis (4条数据)
# 已处理 IRL-Triathlon (4条数据)
# 已处理 IRL-Wrestling (5条数据)
# 已处理 IRQ-Athletics (12条数据)
# 已处理 IRQ-Boxing (9条数据)
# 已处理 IRQ-Football (6条数据)
# 已处理 IRQ-Judo (3条数据)
# 已处理 IRQ-Rowing (3条数据)
# 已处理 IRQ-Shooting (4条数据)
# 已处理 IRQ-Swimming (4条数据)
# 已处理 IRQ-Weightlifting (11条数据)
# 已处理 IRQ-Wrestling (6条数据)
# 已处理 ISL-Athletics (22条数据)
# 已处理 ISL-Badminton (4条数据)
# 已处理 ISL-Gymnastics (4条数据)
# 已处理 ISL-Handball (7条数据)
# 已处理 ISL-Judo (9条数据)
# 已处理 ISL-Sailing (4条数据)
# 已处理 ISL-Shooting (5条数据)
# 已处理 ISL-Swimming (17条数据)
# 已处理 ISL-Weightlifting (4条数据)
# 已处理 ISR-Athletics (17条数据)
# 已处理 ISR-Badminton (4条数据)
# 已处理 ISR-Boxing (3条数据)
# 已处理 ISR-Canoeing (5条数据)
# 已处理 ISR-Fencing (10条数据)
# 已处理 ISR-Football (3条数据)
# 已处理 ISR-Gymnastics (9条数据)
# 已处理 ISR-Judo (11条数据)
# 已处理 ISR-Rhythmic Gymnastics (9条数据)
# 已处理 ISR-Sailing (13条数据)
# 已处理 ISR-Shooting (17条数据)
# 已处理 ISR-Swimming (18条数据)
# 已处理 ISR-Synchronized Swimming (4条数据)
# 已处理 ISR-Taekwondo (5条数据)
# 已处理 ISR-Tennis (6条数据)
# 已处理 ISR-Triathlon (3条数据)
# 已处理 ISR-Weightlifting (8条数据)
# 已处理 ISR-Wrestling (8条数据)
# 已处理 ISV-Athletics (14条数据)
# 已处理 ISV-Boxing (7条数据)
# 已处理 ISV-Equestrianism (4条数据)
# 已处理 ISV-Sailing (12条数据)
# 已处理 ISV-Shooting (9条数据)
# 已处理 ISV-Swimming (12条数据)
# 已处理 ITA-Archery (14条数据)
# 已处理 ITA-Art Competitions (7条数据)
# 已处理 ITA-Athletics (29条数据)
# 已处理 ITA-Badminton (4条数据)
# 已处理 ITA-Baseball (4条数据)
# 已处理 ITA-Basketball (15条数据)
# 已处理 ITA-Beach Volleyball (8条数据)
# 已处理 ITA-Boxing (25条数据)
# 已处理 ITA-Canoeing (17条数据)
# 已处理 ITA-Cycling (27条数据)
# 已处理 ITA-Diving (25条数据)
# 已处理 ITA-Equestrianism (23条数据)
# 已处理 ITA-Fencing (29条数据)
# 已处理 ITA-Football (15条数据)
# 已处理 ITA-Golf (3条数据)
# 已处理 ITA-Gymnastics (26条数据)
# 已处理 ITA-Judo (15条数据)
# 已处理 ITA-Modern Pentathlon (25条数据)
# 已处理 ITA-Rhythmic Gymnastics (11条数据)
# 已处理 ITA-Rowing (27条数据)
# 已处理 ITA-Sailing (24条数据)
# 已处理 ITA-Shooting (26条数据)
# 已处理 ITA-Swimming (27条数据)
# 已处理 ITA-Synchronized Swimming (8条数据)
# 已处理 ITA-Table Tennis (8条数据)
# 已处理 ITA-Taekwondo (6条数据)
# 已处理 ITA-Tennis (12条数据)
# 已处理 ITA-Trampolining (3条数据)
# 已处理 ITA-Triathlon (7条数据)
# 已处理 ITA-Volleyball (13条数据)
# 已处理 ITA-Water Polo (22条数据)
# 已处理 ITA-Weightlifting (25条数据)
# 已处理 ITA-Wrestling (27条数据)
# 已处理 IVB-Athletics (11条数据)
# 已处理 IVB-Sailing (5条数据)
# 已处理 JAM-Athletics (19条数据)
# 已处理 JAM-Boxing (10条数据)
# 已处理 JAM-Cycling (8条数据)
# 已处理 JAM-Diving (4条数据)
# 已处理 JAM-Sailing (6条数据)
# 已处理 JAM-Swimming (11条数据)
# 已处理 JAM-Table Tennis (3条数据)
# 已处理 JAM-Weightlifting (4条数据)
# 已处理 JOR-Athletics (10条数据)
# 已处理 JOR-Boxing (5条数据)
# 已处理 JOR-Equestrianism (4条数据)
# 已处理 JOR-Shooting (6条数据)
# 已处理 JOR-Swimming (8条数据)
# 已处理 JOR-Table Tennis (6条数据)
# 已处理 JOR-Taekwondo (7条数据)
# 已处理 JPN-Archery (13条数据)
# 已处理 JPN-Athletics (24条数据)
# 已处理 JPN-Badminton (9条数据)
# 已处理 JPN-Baseball (5条数据)
# 已处理 JPN-Basketball (11条数据)
# 已处理 JPN-Beach Volleyball (7条数据)
# 已处理 JPN-Boxing (21条数据)
# 已处理 JPN-Canoeing (13条数据)
# 已处理 JPN-Cycling (16条数据)
# 已处理 JPN-Diving (22条数据)
# 已处理 JPN-Equestrianism (19条数据)
# 已处理 JPN-Fencing (18条数据)
# 已处理 JPN-Football (12条数据)
# 已处理 JPN-Golf (3条数据)
# 已处理 JPN-Gymnastics (18条数据)
# 已处理 JPN-Handball (6条数据)
# 已处理 JPN-Hockey (11条数据)
# 已处理 JPN-Judo (14条数据)
# 已处理 JPN-Modern Pentathlon (13条数据)
# 已处理 JPN-Rhythmic Gymnastics (10条数据)
# 已处理 JPN-Rowing (21条数据)
# 已处理 JPN-Rugby Sevens (3条数据)
# 已处理 JPN-Sailing (17条数据)
# 已处理 JPN-Shooting (18条数据)
# 已处理 JPN-Softball (4条数据)
# 已处理 JPN-Swimming (23条数据)
# 已处理 JPN-Synchronized Swimming (9条数据)
# 已处理 JPN-Table Tennis (10条数据)
# 已处理 JPN-Taekwondo (6条数据)
# 已处理 JPN-Tennis (12条数据)
# 已处理 JPN-Trampolining (5条数据)
# 已处理 JPN-Triathlon (7条数据)
# 已处理 JPN-Volleyball (14条数据)
# 已处理 JPN-Water Polo (10条数据)
# 已处理 JPN-Weightlifting (18条数据)
# 已处理 JPN-Wrestling (22条数据)
# 已处理 KAZ-Archery (8条数据)
# 已处理 KAZ-Athletics (8条数据)
# 已处理 KAZ-Boxing (8条数据)
# 已处理 KAZ-Canoeing (6条数据)
# 已处理 KAZ-Cycling (6条数据)
# 已处理 KAZ-Fencing (6条数据)
# 已处理 KAZ-Gymnastics (4条数据)
# 已处理 KAZ-Judo (8条数据)
# 已处理 KAZ-Modern Pentathlon (7条数据)
# 已处理 KAZ-Rhythmic Gymnastics (6条数据)
# 已处理 KAZ-Rowing (6条数据)
# 已处理 KAZ-Shooting (8条数据)
# 已处理 KAZ-Swimming (8条数据)
# 已处理 KAZ-Synchronized Swimming (5条数据)
# 已处理 KAZ-Table Tennis (4条数据)
# 已处理 KAZ-Taekwondo (6条数据)
# 已处理 KAZ-Tennis (4条数据)
# 已处理 KAZ-Triathlon (4条数据)
# 已处理 KAZ-Water Polo (4条数据)
# 已处理 KAZ-Weightlifting (7条数据)
# 已处理 KAZ-Wrestling (8条数据)
# 已处理 KEN-Archery (3条数据)
# 已处理 KEN-Athletics (16条数据)
# 已处理 KEN-Boxing (12条数据)
# 已处理 KEN-Hockey (7条数据)
# 已处理 KEN-Judo (4条数据)
# 已处理 KEN-Rugby Sevens (3条数据)
# 已处理 KEN-Shooting (9条数据)
# 已处理 KEN-Swimming (8条数据)
# 已处理 KEN-Volleyball (4条数据)
# 已处理 KEN-Weightlifting (6条数据)
# 已处理 KGZ-Athletics (8条数据)
# 已处理 KGZ-Boxing (6条数据)
# 已处理 KGZ-Cycling (3条数据)
# 已处理 KGZ-Fencing (3条数据)
# 已处理 KGZ-Judo (8条数据)
# 已处理 KGZ-Shooting (6条数据)
# 已处理 KGZ-Swimming (8条数据)
# 已处理 KGZ-Weightlifting (6条数据)
# 已处理 KGZ-Wrestling (8条数据)
# 已处理 KIR-Athletics (6条数据)
# 已处理 KIR-Weightlifting (6条数据)
# 已处理 KOR-Archery (11条数据)
# 已处理 KOR-Athletics (18条数据)
# 已处理 KOR-Badminton (9条数据)
# 已处理 KOR-Baseball (3条数据)
# 已处理 KOR-Basketball (11条数据)
# 已处理 KOR-Boxing (19条数据)
# 已处理 KOR-Canoeing (7条数据)
# 已处理 KOR-Cycling (15条数据)
# 已处理 KOR-Diving (12条数据)
# 已处理 KOR-Equestrianism (8条数据)
# 已处理 KOR-Fencing (12条数据)
# 已处理 KOR-Football (11条数据)
# 已处理 KOR-Golf (3条数据)
# 已处理 KOR-Gymnastics (12条数据)
# 已处理 KOR-Handball (11条数据)
# 已处理 KOR-Hockey (8条数据)
# 已处理 KOR-Judo (14条数据)
# 已处理 KOR-Modern Pentathlon (11条数据)
# 已处理 KOR-Rhythmic Gymnastics (5条数据)
# 已处理 KOR-Rowing (11条数据)
# 已处理 KOR-Sailing (11条数据)
# 已处理 KOR-Shooting (17条数据)
# 已处理 KOR-Swimming (14条数据)
# 已处理 KOR-Synchronized Swimming (4条数据)
# 已处理 KOR-Table Tennis (10条数据)
# 已处理 KOR-Taekwondo (7条数据)
# 已处理 KOR-Tennis (7条数据)
# 已处理 KOR-Volleyball (13条数据)
# 已处理 KOR-Weightlifting (18条数据)
# 已处理 KOR-Wrestling (19条数据)
# 已处理 KOS-Athletics (3条数据)
# 已处理 KOS-Judo (3条数据)
# 已处理 KOS-Swimming (3条数据)
# 已处理 KSA-Athletics (12条数据)
# 已处理 KSA-Equestrianism (5条数据)
# 已处理 KSA-Fencing (3条数据)
# 已处理 KSA-Football (3条数据)
# 已处理 KSA-Judo (3条数据)
# 已处理 KSA-Shooting (9条数据)
# 已处理 KSA-Swimming (6条数据)
# 已处理 KSA-Table Tennis (3条数据)
# 已处理 KSA-Weightlifting (5条数据)
# 已处理 KUW-Athletics (14条数据)
# 已处理 KUW-Diving (5条数据)
# 已处理 KUW-Fencing (8条数据)
# 已处理 KUW-Football (3条数据)
# 已处理 KUW-Judo (8条数据)
# 已处理 KUW-Rowing (3条数据)
# 已处理 KUW-Shooting (8条数据)
# 已处理 KUW-Swimming (11条数据)
# 已处理 KUW-Table Tennis (3条数据)
# 已处理 LAO-Athletics (11条数据)
# 已处理 LAO-Boxing (3条数据)
# 已处理 LAO-Swimming (7条数据)
# 已处理 LAT-Art Competitions (3条数据)
# 已处理 LAT-Athletics (13条数据)
# 已处理 LAT-Beach Volleyball (5条数据)
# 已处理 LAT-Boxing (3条数据)
# 已处理 LAT-Canoeing (7条数据)
# 已处理 LAT-Cycling (10条数据)
# 已处理 LAT-Gymnastics (4条数据)
# 已处理 LAT-Judo (7条数据)
# 已处理 LAT-Modern Pentathlon (9条数据)
# 已处理 LAT-Rowing (3条数据)
# 已处理 LAT-Sailing (6条数据)
# 已处理 LAT-Shooting (10条数据)
# 已处理 LAT-Swimming (9条数据)
# 已处理 LAT-Tennis (5条数据)
# 已处理 LAT-Weightlifting (11条数据)
# 已处理 LAT-Wrestling (10条数据)
# 已处理 LBA-Athletics (12条数据)
# 已处理 LBA-Cycling (4条数据)
# 已处理 LBA-Judo (7条数据)
# 已处理 LBA-Rowing (3条数据)
# 已处理 LBA-Swimming (7条数据)
# 已处理 LBA-Taekwondo (3条数据)
# 已处理 LBA-Weightlifting (5条数据)
# 已处理 LBR-Athletics (14条数据)
# 已处理 LCA-Athletics (8条数据)
# 已处理 LCA-Sailing (5条数据)
# 已处理 LCA-Swimming (7条数据)
# 已处理 LES-Athletics (13条数据)
# 已处理 LES-Boxing (5条数据)
# 已处理 LES-Taekwondo (3条数据)
# 已处理 LIB-Athletics (12条数据)
# 已处理 LIB-Boxing (6条数据)
# 已处理 LIB-Cycling (6条数据)
# 已处理 LIB-Fencing (10条数据)
# 已处理 LIB-Judo (9条数据)
# 已处理 LIB-Shooting (12条数据)
# 已处理 LIB-Swimming (11条数据)
# 已处理 LIB-Table Tennis (3条数据)
# 已处理 LIB-Weightlifting (9条数据)
# 已处理 LIB-Wrestling (9条数据)
# 已处理 LIE-Athletics (12条数据)
# 已处理 LIE-Cycling (6条数据)
# 已处理 LIE-Judo (8条数据)
# 已处理 LIE-Shooting (9条数据)
# 已处理 LIE-Swimming (3条数据)
# 已处理 LTU-Athletics (10条数据)
# 已处理 LTU-Basketball (7条数据)
# 已处理 LTU-Boxing (8条数据)
# 已处理 LTU-Canoeing (7条数据)
# 已处理 LTU-Cycling (9条数据)
# 已处理 LTU-Gymnastics (4条数据)
# 已处理 LTU-Judo (8条数据)
# 已处理 LTU-Modern Pentathlon (9条数据)
# 已处理 LTU-Rowing (9条数据)
# 已处理 LTU-Sailing (8条数据)
# 已处理 LTU-Shooting (7条数据)
# 已处理 LTU-Swimming (9条数据)
# 已处理 LTU-Table Tennis (3条数据)
# 已处理 LTU-Weightlifting (7条数据)
# 已处理 LTU-Wrestling (9条数据)
# 已处理 LUX-Archery (9条数据)
# 已处理 LUX-Art Competitions (4条数据)
# 已处理 LUX-Athletics (22条数据)
# 已处理 LUX-Boxing (6条数据)
# 已处理 LUX-Canoeing (4条数据)
# 已处理 LUX-Cycling (16条数据)
# 已处理 LUX-Fencing (9条数据)
# 已处理 LUX-Football (6条数据)
# 已处理 LUX-Gymnastics (10条数据)
# 已处理 LUX-Judo (4条数据)
# 已处理 LUX-Shooting (11条数据)
# 已处理 LUX-Swimming (18条数据)
# 已处理 LUX-Table Tennis (6条数据)
# 已处理 LUX-Tennis (6条数据)
# 已处理 LUX-Triathlon (5条数据)
# 已处理 LUX-Weightlifting (5条数据)
# 已处理 LUX-Wrestling (8条数据)
# 已处理 MAD-Athletics (14条数据)
# 已处理 MAD-Boxing (7条数据)
# 已处理 MAD-Judo (10条数据)
# 已处理 MAD-Swimming (10条数据)
# 已处理 MAD-Tennis (3条数据)
# 已处理 MAD-Weightlifting (5条数据)
# 已处理 MAR-Athletics (15条数据)
# 已处理 MAR-Boxing (16条数据)
# 已处理 MAR-Canoeing (3条数据)
# 已处理 MAR-Cycling (4条数据)
# 已处理 MAR-Fencing (7条数据)
# 已处理 MAR-Football (8条数据)
# 已处理 MAR-Golf (3条数据)
# 已处理 MAR-Judo (11条数据)
# 已处理 MAR-Shooting (5条数据)
# 已处理 MAR-Swimming (7条数据)
# 已处理 MAR-Taekwondo (7条数据)
# 已处理 MAR-Tennis (4条数据)
# 已处理 MAR-Weightlifting (7条数据)
# 已处理 MAR-Wrestling (12条数据)
# 已处理 MAS-Archery (6条数据)
# 已处理 MAS-Athletics (15条数据)
# 已处理 MAS-Badminton (9条数据)
# 已处理 MAS-Cycling (11条数据)
# 已处理 MAS-Diving (7条数据)
# 已处理 MAS-Golf (3条数据)
# 已处理 MAS-Hockey (8条数据)
# 已处理 MAS-Sailing (8条数据)
# 已处理 MAS-Shooting (14条数据)
# 已处理 MAS-Swimming (14条数据)
# 已处理 MAS-Taekwondo (3条数据)
# 已处理 MAS-Weightlifting (6条数据)
# 已处理 MAW-Athletics (12条数据)
# 已处理 MAW-Boxing (3条数据)
# 已处理 MAW-Cycling (3条数据)
# 已处理 MAW-Swimming (6条数据)
# 已处理 MDA-Archery (5条数据)
# 已处理 MDA-Athletics (8条数据)
# 已处理 MDA-Boxing (5条数据)
# 已处理 MDA-Cycling (4条数据)
# 已处理 MDA-Judo (8条数据)
# 已处理 MDA-Shooting (7条数据)
# 已处理 MDA-Swimming (8条数据)
# 已处理 MDA-Weightlifting (8条数据)
# 已处理 MDA-Wrestling (8条数据)
# 已处理 MDV-Athletics (10条数据)
# 已处理 MDV-Badminton (3条数据)
# 已处理 MDV-Swimming (9条数据)
# 已处理 MEX-Archery (12条数据)
# 已处理 MEX-Athletics (24条数据)
# 已处理 MEX-Badminton (5条数据)
# 已处理 MEX-Basketball (7条数据)
# 已处理 MEX-Beach Volleyball (6条数据)
# 已处理 MEX-Boxing (22条数据)
# 已处理 MEX-Canoeing (10条数据)
# 已处理 MEX-Cycling (18条数据)
# 已处理 MEX-Diving (23条数据)
# 已处理 MEX-Equestrianism (17条数据)
# 已处理 MEX-Fencing (17条数据)
# 已处理 MEX-Football (12条数据)
# 已处理 MEX-Golf (3条数据)
# 已处理 MEX-Gymnastics (15条数据)
# 已处理 MEX-Judo (15条数据)
# 已处理 MEX-Modern Pentathlon (21条数据)
# 已处理 MEX-Rowing (18条数据)
# 已处理 MEX-Sailing (16条数据)
# 已处理 MEX-Shooting (23条数据)
# 已处理 MEX-Swimming (21条数据)
# 已处理 MEX-Synchronized Swimming (9条数据)
# 已处理 MEX-Table Tennis (5条数据)
# 已处理 MEX-Taekwondo (7条数据)
# 已处理 MEX-Tennis (7条数据)
# 已处理 MEX-Triathlon (6条数据)
# 已处理 MEX-Water Polo (4条数据)
# 已处理 MEX-Weightlifting (17条数据)
# 已处理 MEX-Wrestling (19条数据)
# 已处理 MGL-Archery (10条数据)
# 已处理 MGL-Athletics (12条数据)
# 已处理 MGL-Boxing (13条数据)
# 已处理 MGL-Cycling (4条数据)
# 已处理 MGL-Gymnastics (3条数据)
# 已处理 MGL-Judo (13条数据)
# 已处理 MGL-Shooting (15条数据)
# 已处理 MGL-Swimming (7条数据)
# 已处理 MGL-Weightlifting (8条数据)
# 已处理 MGL-Wrestling (15条数据)
# 已处理 MHL-Athletics (4条数据)
# 已处理 MHL-Swimming (5条数据)
# 已处理 MKD-Athletics (7条数据)
# 已处理 MKD-Canoeing (4条数据)
# 已处理 MKD-Judo (3条数据)
# 已处理 MKD-Shooting (7条数据)
# 已处理 MKD-Swimming (8条数据)
# 已处理 MKD-Wrestling (6条数据)
# 已处理 MLI-Athletics (15条数据)
# 已处理 MLI-Boxing (5条数据)
# 已处理 MLI-Judo (9条数据)
# 已处理 MLI-Swimming (7条数据)
# 已处理 MLI-Taekwondo (5条数据)
# 已处理 MLT-Archery (3条数据)
# 已处理 MLT-Athletics (12条数据)
# 已处理 MLT-Cycling (3条数据)
# 已处理 MLT-Judo (7条数据)
# 已处理 MLT-Sailing (7条数据)
# 已处理 MLT-Shooting (14条数据)
# 已处理 MLT-Swimming (9条数据)
# 已处理 MNE-Athletics (5条数据)
# 已处理 MNE-Boxing (3条数据)
# 已处理 MNE-Handball (3条数据)
# 已处理 MNE-Judo (4条数据)
# 已处理 MNE-Sailing (4条数据)
# 已处理 MNE-Shooting (3条数据)
# 已处理 MNE-Swimming (4条数据)
# 已处理 MNE-Water Polo (5条数据)
# 已处理 MON-Art Competitions (4条数据)
# 已处理 MON-Athletics (10条数据)
# 已处理 MON-Fencing (4条数据)
# 已处理 MON-Judo (9条数据)
# 已处理 MON-Rowing (5条数据)
# 已处理 MON-Sailing (7条数据)
# 已处理 MON-Shooting (15条数据)
# 已处理 MON-Swimming (9条数据)
# 已处理 MOZ-Athletics (12条数据)
# 已处理 MOZ-Boxing (5条数据)
# 已处理 MOZ-Judo (5条数据)
# 已处理 MOZ-Swimming (12条数据)
# 已处理 MRI-Archery (3条数据)
# 已处理 MRI-Athletics (11条数据)
# 已处理 MRI-Badminton (7条数据)
# 已处理 MRI-Boxing (8条数据)
# 已处理 MRI-Judo (6条数据)
# 已处理 MRI-Swimming (9条数据)
# 已处理 MRI-Triathlon (3条数据)
# 已处理 MRI-Weightlifting (7条数据)
# 已处理 MTN-Athletics (10条数据)
# 已处理 MYA-Archery (5条数据)
# 已处理 MYA-Athletics (14条数据)
# 已处理 MYA-Boxing (8条数据)
# 已处理 MYA-Judo (3条数据)
# 已处理 MYA-Shooting (5条数据)
# 已处理 MYA-Swimming (6条数据)
# 已处理 MYA-Weightlifting (9条数据)
# 已处理 NAM-Athletics (9条数据)
# 已处理 NAM-Boxing (8条数据)
# 已处理 NAM-Cycling (5条数据)
# 已处理 NAM-Shooting (6条数据)
# 已处理 NAM-Swimming (3条数据)
# 已处理 NCA-Athletics (13条数据)
# 已处理 NCA-Boxing (7条数据)
# 已处理 NCA-Judo (5条数据)
# 已处理 NCA-Shooting (8条数据)
# 已处理 NCA-Swimming (10条数据)
# 已处理 NCA-Weightlifting (9条数据)
# 已处理 NED-Archery (13条数据)
# 已处理 NED-Art Competitions (5条数据)
# 已处理 NED-Athletics (26条数据)
# 已处理 NED-Badminton (8条数据)
# 已处理 NED-Baseball (4条数据)
# 已处理 NED-Beach Volleyball (8条数据)
# 已处理 NED-Boxing (16条数据)
# 已处理 NED-Canoeing (15条数据)
# 已处理 NED-Cycling (23条数据)
# 已处理 NED-Diving (14条数据)
# 已处理 NED-Equestrianism (19条数据)
# 已处理 NED-Fencing (19条数据)
# 已处理 NED-Football (10条数据)
# 已处理 NED-Golf (3条数据)
# 已处理 NED-Gymnastics (12条数据)
# 已处理 NED-Handball (3条数据)
# 已处理 NED-Hockey (20条数据)
# 已处理 NED-Judo (14条数据)
# 已处理 NED-Modern Pentathlon (6条数据)
# 已处理 NED-Rowing (26条数据)
# 已处理 NED-Sailing (25条数据)
# 已处理 NED-Shooting (18条数据)
# 已处理 NED-Swimming (26条数据)
# 已处理 NED-Synchronized Swimming (4条数据)
# 已处理 NED-Table Tennis (10条数据)
# 已处理 NED-Taekwondo (5条数据)
# 已处理 NED-Tennis (12条数据)
# 已处理 NED-Trampolining (3条数据)
# 已处理 NED-Triathlon (7条数据)
# 已处理 NED-Volleyball (8条数据)
# 已处理 NED-Water Polo (20条数据)
# 已处理 NED-Weightlifting (7条数据)
# 已处理 NED-Wrestling (9条数据)
# 已处理 NEP-Athletics (15条数据)
# 已处理 NEP-Boxing (4条数据)
# 已处理 NEP-Judo (5条数据)
# 已处理 NEP-Shooting (9条数据)
# 已处理 NEP-Swimming (8条数据)
# 已处理 NEP-Taekwondo (3条数据)
# 已处理 NEP-Weightlifting (5条数据)
# 已处理 NGR-Athletics (18条数据)
# 已处理 NGR-Badminton (4条数据)
# 已处理 NGR-Basketball (5条数据)
# 已处理 NGR-Boxing (15条数据)
# 已处理 NGR-Football (9条数据)
# 已处理 NGR-Judo (6条数据)
# 已处理 NGR-Swimming (7条数据)
# 已处理 NGR-Table Tennis (10条数据)
# 已处理 NGR-Taekwondo (5条数据)
# 已处理 NGR-Weightlifting (11条数据)
# 已处理 NGR-Wrestling (12条数据)
# 已处理 NIG-Athletics (11条数据)
# 已处理 NIG-Boxing (6条数据)
# 已处理 NIG-Judo (5条数据)
# 已处理 NIG-Swimming (7条数据)
# 已处理 NIG-Taekwondo (3条数据)
# 已处理 NOR-Archery (8条数据)
# 已处理 NOR-Art Competitions (5条数据)
# 已处理 NOR-Athletics (28条数据)
# 已处理 NOR-Badminton (3条数据)
# 已处理 NOR-Beach Volleyball (7条数据)
# 已处理 NOR-Boxing (13条数据)
# 已处理 NOR-Canoeing (16条数据)
# 已处理 NOR-Cycling (19条数据)
# 已处理 NOR-Diving (11条数据)
# 已处理 NOR-Equestrianism (11条数据)
# 已处理 NOR-Fencing (15条数据)
# 已处理 NOR-Football (8条数据)
# 已处理 NOR-Golf (3条数据)
# 已处理 NOR-Gymnastics (15条数据)
# 已处理 NOR-Handball (10条数据)
# 已处理 NOR-Modern Pentathlon (3条数据)
# 已处理 NOR-Rowing (21条数据)
# 已处理 NOR-Sailing (25条数据)
# 已处理 NOR-Shooting (26条数据)
# 已处理 NOR-Swimming (20条数据)
# 已处理 NOR-Taekwondo (6条数据)
# 已处理 NOR-Tennis (7条数据)
# 已处理 NOR-Triathlon (3条数据)
# 已处理 NOR-Weightlifting (9条数据)
# 已处理 NOR-Wrestling (26条数据)
# 已处理 NRU-Weightlifting (7条数据)
# 已处理 NZL-Archery (7条数据)
# 已处理 NZL-Athletics (24条数据)
# 已处理 NZL-Badminton (4条数据)
# 已处理 NZL-Basketball (3条数据)
# 已处理 NZL-Boxing (16条数据)
# 已处理 NZL-Canoeing (11条数据)
# 已处理 NZL-Cycling (19条数据)
# 已处理 NZL-Diving (6条数据)
# 已处理 NZL-Equestrianism (12条数据)
# 已处理 NZL-Fencing (5条数据)
# 已处理 NZL-Football (5条数据)
# 已处理 NZL-Golf (3条数据)
# 已处理 NZL-Gymnastics (4条数据)
# 已处理 NZL-Hockey (15条数据)
# 已处理 NZL-Judo (10条数据)
# 已处理 NZL-Rowing (20条数据)
# 已处理 NZL-Rugby Sevens (3条数据)
# 已处理 NZL-Sailing (17条数据)
# 已处理 NZL-Shooting (14条数据)
# 已处理 NZL-Swimming (21条数据)
# 已处理 NZL-Table Tennis (5条数据)
# 已处理 NZL-Taekwondo (5条数据)
# 已处理 NZL-Tennis (7条数据)
# 已处理 NZL-Triathlon (7条数据)
# 已处理 NZL-Weightlifting (16条数据)
# 已处理 NZL-Wrestling (10条数据)
# 已处理 OMA-Athletics (11条数据)
# 已处理 OMA-Shooting (11条数据)
# 已处理 OMA-Swimming (5条数据)
# 已处理 PAK-Athletics (18条数据)
# 已处理 PAK-Boxing (13条数据)
# 已处理 PAK-Cycling (5条数据)
# 已处理 PAK-Hockey (16条数据)
# 已处理 PAK-Sailing (3条数据)
# 已处理 PAK-Shooting (11条数据)
# 已处理 PAK-Swimming (11条数据)
# 已处理 PAK-Weightlifting (8条数据)
# 已处理 PAK-Wrestling (10条数据)
# 已处理 PAN-Athletics (15条数据)
# 已处理 PAN-Boxing (6条数据)
# 已处理 PAN-Fencing (3条数据)
# 已处理 PAN-Judo (6条数据)
# 已处理 PAN-Shooting (3条数据)
# 已处理 PAN-Swimming (13条数据)
# 已处理 PAN-Weightlifting (11条数据)
# 已处理 PAN-Wrestling (9条数据)
# 已处理 PAR-Athletics (13条数据)
# 已处理 PAR-Fencing (5条数据)
# 已处理 PAR-Football (3条数据)
# 已处理 PAR-Golf (3条数据)
# 已处理 PAR-Judo (6条数据)
# 已处理 PAR-Rowing (5条数据)
# 已处理 PAR-Shooting (5条数据)
# 已处理 PAR-Swimming (10条数据)
# 已处理 PAR-Table Tennis (3条数据)
# 已处理 PAR-Tennis (6条数据)
# 已处理 PER-Athletics (18条数据)
# 已处理 PER-Badminton (6条数据)
# 已处理 PER-Basketball (3条数据)
# 已处理 PER-Boxing (5条数据)
# 已处理 PER-Cycling (6条数据)
# 已处理 PER-Fencing (7条数据)
# 已处理 PER-Judo (7条数据)
# 已处理 PER-Rowing (8条数据)
# 已处理 PER-Sailing (7条数据)
# 已处理 PER-Shooting (19条数据)
# 已处理 PER-Swimming (16条数据)
# 已处理 PER-Table Tennis (4条数据)
# 已处理 PER-Taekwondo (3条数据)
# 已处理 PER-Tennis (3条数据)
# 已处理 PER-Volleyball (7条数据)
# 已处理 PER-Weightlifting (10条数据)
# 已处理 PER-Wrestling (9条数据)
# 已处理 PHI-Archery (6条数据)
# 已处理 PHI-Athletics (23条数据)
# 已处理 PHI-Basketball (7条数据)
# 已处理 PHI-Boxing (21条数据)
# 已处理 PHI-Cycling (7条数据)
# 已处理 PHI-Equestrianism (3条数据)
# 已处理 PHI-Fencing (3条数据)
# 已处理 PHI-Golf (3条数据)
# 已处理 PHI-Judo (8条数据)
# 已处理 PHI-Rowing (4条数据)
# 已处理 PHI-Sailing (8条数据)
# 已处理 PHI-Shooting (17条数据)
# 已处理 PHI-Swimming (22条数据)
# 已处理 PHI-Taekwondo (5条数据)
# 已处理 PHI-Weightlifting (14条数据)
# 已处理 PHI-Wrestling (8条数据)
# 已处理 PLE-Athletics (8条数据)
# 已处理 PLE-Judo (4条数据)
# 已处理 PLE-Swimming (7条数据)
# 已处理 PLW-Athletics (7条数据)
# 已处理 PLW-Swimming (7条数据)
# 已处理 PLW-Wrestling (3条数据)
# 已处理 PNG-Athletics (12条数据)
# 已处理 PNG-Boxing (8条数据)
# 已处理 PNG-Sailing (3条数据)
# 已处理 PNG-Swimming (7条数据)
# 已处理 PNG-Taekwondo (4条数据)
# 已处理 PNG-Weightlifting (10条数据)
# 已处理 POL-Archery (13条数据)
# 已处理 POL-Art Competitions (5条数据)
# 已处理 POL-Athletics (23条数据)
# 已处理 POL-Badminton (7条数据)
# 已处理 POL-Basketball (7条数据)
# 已处理 POL-Beach Volleyball (4条数据)
# 已处理 POL-Boxing (22条数据)
# 已处理 POL-Canoeing (17条数据)
# 已处理 POL-Cycling (17条数据)
# 已处理 POL-Diving (7条数据)
# 已处理 POL-Equestrianism (14条数据)
# 已处理 POL-Fencing (23条数据)
# 已处理 POL-Football (7条数据)
# 已处理 POL-Gymnastics (13条数据)
# 已处理 POL-Handball (5条数据)
# 已处理 POL-Hockey (5条数据)
# 已处理 POL-Judo (13条数据)
# 已处理 POL-Modern Pentathlon (15条数据)
# 已处理 POL-Rhythmic Gymnastics (7条数据)
# 已处理 POL-Rowing (22条数据)
# 已处理 POL-Sailing (17条数据)
# 已处理 POL-Shooting (20条数据)
# 已处理 POL-Swimming (19条数据)
# 已处理 POL-Table Tennis (10条数据)
# 已处理 POL-Taekwondo (4条数据)
# 已处理 POL-Tennis (9条数据)
# 已处理 POL-Triathlon (4条数据)
# 已处理 POL-Volleyball (12条数据)
# 已处理 POL-Weightlifting (18条数据)
# 已处理 POL-Wrestling (20条数据)
# 已处理 POR-Archery (6条数据)
# 已处理 POR-Athletics (24条数据)
# 已处理 POR-Badminton (6条数据)
# 已处理 POR-Beach Volleyball (3条数据)
# 已处理 POR-Canoeing (8条数据)
# 已处理 POR-Cycling (7条数据)
# 已处理 POR-Equestrianism (17条数据)
# 已处理 POR-Fencing (16条数据)
# 已处理 POR-Football (4条数据)
# 已处理 POR-Gymnastics (10条数据)
# 已处理 POR-Judo (15条数据)
# 已处理 POR-Modern Pentathlon (7条数据)
# 已处理 POR-Rowing (9条数据)
# 已处理 POR-Sailing (22条数据)
# 已处理 POR-Shooting (21条数据)
# 已处理 POR-Swimming (18条数据)
# 已处理 POR-Table Tennis (5条数据)
# 已处理 POR-Taekwondo (3条数据)
# 已处理 POR-Tennis (7条数据)
# 已处理 POR-Trampolining (4条数据)
# 已处理 POR-Triathlon (6条数据)
# 已处理 POR-Weightlifting (9条数据)
# 已处理 POR-Wrestling (10条数据)
# 已处理 PRK-Archery (8条数据)
# 已处理 PRK-Athletics (11条数据)
# 已处理 PRK-Boxing (10条数据)
# 已处理 PRK-Diving (8条数据)
# 已处理 PRK-Football (3条数据)
# 已处理 PRK-Gymnastics (8条数据)
# 已处理 PRK-Judo (11条数据)
# 已处理 PRK-Shooting (10条数据)
# 已处理 PRK-Synchronized Swimming (3条数据)
# 已处理 PRK-Table Tennis (7条数据)
# 已处理 PRK-Weightlifting (10条数据)
# 已处理 PRK-Wrestling (11条数据)
# 已处理 PUR-Archery (6条数据)
# 已处理 PUR-Athletics (19条数据)
# 已处理 PUR-Basketball (11条数据)
# 已处理 PUR-Boxing (18条数据)
# 已处理 PUR-Cycling (4条数据)
# 已处理 PUR-Diving (9条数据)
# 已处理 PUR-Equestrianism (6条数据)
# 已处理 PUR-Fencing (7条数据)
# 已处理 PUR-Gymnastics (6条数据)
# 已处理 PUR-Judo (13条数据)
# 已处理 PUR-Rowing (3条数据)
# 已处理 PUR-Sailing (12条数据)
# 已处理 PUR-Shooting (19条数据)
# 已处理 PUR-Swimming (15条数据)
# 已处理 PUR-Table Tennis (3条数据)
# 已处理 PUR-Taekwondo (4条数据)
# 已处理 PUR-Tennis (3条数据)
# 已处理 PUR-Weightlifting (14条数据)
# 已处理 PUR-Wrestling (10条数据)
# 已处理 QAT-Athletics (11条数据)
# 已处理 QAT-Beach Volleyball (3条数据)
# 已处理 QAT-Shooting (10条数据)
# 已处理 QAT-Swimming (7条数据)
# 已处理 QAT-Table Tennis (4条数据)
# 已处理 QAT-Weightlifting (5条数据)
# 已处理 ROU-Archery (4条数据)
# 已处理 ROU-Athletics (21条数据)
# 已处理 ROU-Boxing (20条数据)
# 已处理 ROU-Canoeing (16条数据)
# 已处理 ROU-Cycling (9条数据)
# 已处理 ROU-Diving (7条数据)
# 已处理 ROU-Equestrianism (6条数据)
# 已处理 ROU-Fencing (21条数据)
# 已处理 ROU-Football (4条数据)
# 已处理 ROU-Gymnastics (17条数据)
# 已处理 ROU-Handball (9条数据)
# 已处理 ROU-Judo (11条数据)
# 已处理 ROU-Modern Pentathlon (6条数据)
# 已处理 ROU-Rhythmic Gymnastics (5条数据)
# 已处理 ROU-Rowing (18条数据)
# 已处理 ROU-Sailing (3条数据)
# 已处理 ROU-Shooting (21条数据)
# 已处理 ROU-Swimming (17条数据)
# 已处理 ROU-Table Tennis (9条数据)
# 已处理 ROU-Tennis (10条数据)
# 已处理 ROU-Volleyball (3条数据)
# 已处理 ROU-Water Polo (10条数据)
# 已处理 ROU-Weightlifting (16条数据)
# 已处理 ROU-Wrestling (20条数据)
# 已处理 RSA-Archery (7条数据)
# 已处理 RSA-Art Competitions (3条数据)
# 已处理 RSA-Athletics (21条数据)
# 已处理 RSA-Badminton (6条数据)
# 已处理 RSA-Beach Volleyball (3条数据)
# 已处理 RSA-Boxing (15条数据)
# 已处理 RSA-Canoeing (7条数据)
# 已处理 RSA-Cycling (17条数据)
# 已处理 RSA-Diving (8条数据)
# 已处理 RSA-Equestrianism (3条数据)
# 已处理 RSA-Fencing (6条数据)
# 已处理 RSA-Football (4条数据)
# 已处理 RSA-Golf (3条数据)
# 已处理 RSA-Gymnastics (5条数据)
# 已处理 RSA-Hockey (7条数据)
# 已处理 RSA-Judo (8条数据)
# 已处理 RSA-Modern Pentathlon (6条数据)
# 已处理 RSA-Rowing (14条数据)
# 已处理 RSA-Rugby Sevens (3条数据)
# 已处理 RSA-Sailing (15条数据)
# 已处理 RSA-Shooting (12条数据)
# 已处理 RSA-Swimming (17条数据)
# 已处理 RSA-Tennis (8条数据)
# 已处理 RSA-Triathlon (7条数据)
# 已处理 RSA-Water Polo (3条数据)
# 已处理 RSA-Weightlifting (7条数据)
# 已处理 RSA-Wrestling (13条数据)
# 已处理 RUS-Archery (6条数据)
# 已处理 RUS-Athletics (8条数据)
# 已处理 RUS-Badminton (6条数据)
# 已处理 RUS-Basketball (5条数据)
# 已处理 RUS-Beach Volleyball (4条数据)
# 已处理 RUS-Boxing (6条数据)
# 已处理 RUS-Canoeing (6条数据)
# 已处理 RUS-Cycling (7条数据)
# 已处理 RUS-Diving (7条数据)
# 已处理 RUS-Equestrianism (7条数据)
# 已处理 RUS-Fencing (8条数据)
# 已处理 RUS-Gymnastics (7条数据)
# 已处理 RUS-Handball (6条数据)
# 已处理 RUS-Judo (6条数据)
# 已处理 RUS-Modern Pentathlon (7条数据)
# 已处理 RUS-Rhythmic Gymnastics (6条数据)
# 已处理 RUS-Rowing (7条数据)
# 已处理 RUS-Sailing (7条数据)
# 已处理 RUS-Shooting (7条数据)
# 已处理 RUS-Swimming (7条数据)
# 已处理 RUS-Synchronized Swimming (6条数据)
# 已处理 RUS-Table Tennis (6条数据)
# 已处理 RUS-Taekwondo (4条数据)
# 已处理 RUS-Tennis (7条数据)
# 已处理 RUS-Trampolining (5条数据)
# 已处理 RUS-Triathlon (5条数据)
# 已处理 RUS-Volleyball (6条数据)
# 已处理 RUS-Water Polo (6条数据)
# 已处理 RUS-Weightlifting (5条数据)
# 已处理 RUS-Wrestling (8条数据)
# 已处理 RWA-Athletics (11条数据)
# 已处理 RWA-Cycling (3条数据)
# 已处理 RWA-Swimming (7条数据)
# 已处理 SAM-Athletics (9条数据)
# 已处理 SAM-Boxing (8条数据)
# 已处理 SAM-Canoeing (3条数据)
# 已处理 SAM-Judo (5条数据)
# 已处理 SAM-Weightlifting (10条数据)
# 已处理 SAM-Wrestling (3条数据)
# 已处理 SCG-Athletics (3条数据)
# 已处理 SCG-Basketball (3条数据)
# 已处理 SCG-Canoeing (3条数据)
# 已处理 SCG-Judo (3条数据)
# 已处理 SCG-Shooting (3条数据)
# 已处理 SCG-Swimming (3条数据)
# 已处理 SCG-Table Tennis (3条数据)
# 已处理 SCG-Volleyball (3条数据)
# 已处理 SCG-Water Polo (3条数据)
# 已处理 SEN-Athletics (16条数据)
# 已处理 SEN-Basketball (5条数据)
# 已处理 SEN-Boxing (3条数据)
# 已处理 SEN-Canoeing (3条数据)
# 已处理 SEN-Fencing (6条数据)
# 已处理 SEN-Judo (14条数据)
# 已处理 SEN-Swimming (9条数据)
# 已处理 SEN-Table Tennis (3条数据)
# 已处理 SEN-Taekwondo (4条数据)
# 已处理 SEN-Wrestling (13条数据)
# 已处理 SEY-Athletics (11条数据)
# 已处理 SEY-Boxing (7条数据)
# 已处理 SEY-Judo (5条数据)
# 已处理 SEY-Sailing (7条数据)
# 已处理 SEY-Swimming (9条数据)
# 已处理 SEY-Weightlifting (5条数据)
# 已处理 SGP-Athletics (13条数据)
# 已处理 SGP-Badminton (8条数据)
# 已处理 SGP-Fencing (3条数据)
# 已处理 SGP-Rowing (3条数据)
# 已处理 SGP-Sailing (13条数据)
# 已处理 SGP-Shooting (13条数据)
# 已处理 SGP-Swimming (13条数据)
# 已处理 SGP-Table Tennis (8条数据)
# 已处理 SGP-Weightlifting (6条数据)
# 已处理 SKN-Athletics (8条数据)
# 已处理 SLE-Athletics (13条数据)
# 已处理 SLE-Boxing (6条数据)
# 已处理 SLE-Swimming (4条数据)
# 已处理 SLO-Archery (6条数据)
# 已处理 SLO-Athletics (9条数据)
# 已处理 SLO-Badminton (3条数据)
# 已处理 SLO-Canoeing (7条数据)
# 已处理 SLO-Cycling (7条数据)
# 已处理 SLO-Gymnastics (5条数据)
# 已处理 SLO-Handball (4条数据)
# 已处理 SLO-Judo (7条数据)
# 已处理 SLO-Rowing (7条数据)
# 已处理 SLO-Sailing (9条数据)
# 已处理 SLO-Shooting (8条数据)
# 已处理 SLO-Swimming (9条数据)
# 已处理 SLO-Table Tennis (6条数据)
# 已处理 SLO-Taekwondo (4条数据)
# 已处理 SLO-Tennis (5条数据)
# 已处理 SMR-Archery (4条数据)
# 已处理 SMR-Athletics (12条数据)
# 已处理 SMR-Cycling (7条数据)
# 已处理 SMR-Judo (6条数据)
# 已处理 SMR-Sailing (3条数据)
# 已处理 SMR-Shooting (16条数据)
# 已处理 SMR-Swimming (10条数据)
# 已处理 SMR-Wrestling (3条数据)
# 已处理 SOL-Athletics (10条数据)
# 已处理 SOL-Weightlifting (8条数据)
# 已处理 SOM-Athletics (11条数据)
# 已处理 SRB-Athletics (6条数据)
# 已处理 SRB-Basketball (3条数据)
# 已处理 SRB-Boxing (3条数据)
# 已处理 SRB-Cycling (3条数据)
# 已处理 SRB-Judo (4条数据)
# 已处理 SRB-Rowing (5条数据)
# 已处理 SRB-Shooting (5条数据)
# 已处理 SRB-Swimming (5条数据)
# 已处理 SRB-Table Tennis (5条数据)
# 已处理 SRB-Taekwondo (4条数据)
# 已处理 SRB-Tennis (5条数据)
# 已处理 SRB-Volleyball (5条数据)
# 已处理 SRB-Water Polo (5条数据)
# 已处理 SRB-Wrestling (5条数据)
# 已处理 SRI-Athletics (18条数据)
# 已处理 SRI-Badminton (6条数据)
# 已处理 SRI-Boxing (7条数据)
# 已处理 SRI-Sailing (3条数据)
# 已处理 SRI-Shooting (11条数据)
# 已处理 SRI-Swimming (12条数据)
# 已处理 SRI-Weightlifting (4条数据)
# 已处理 SSD-Athletics (3条数据)
# 已处理 STP-Athletics (8条数据)
# 已处理 SUD-Athletics (14条数据)
# 已处理 SUD-Boxing (5条数据)
# 已处理 SUD-Judo (3条数据)
# 已处理 SUD-Swimming (6条数据)
# 已处理 SUD-Weightlifting (3条数据)
# 已处理 SUI-Archery (6条数据)
# 已处理 SUI-Art Competitions (6条数据)
# 已处理 SUI-Athletics (27条数据)
# 已处理 SUI-Badminton (7条数据)
# 已处理 SUI-Basketball (3条数据)
# 已处理 SUI-Beach Volleyball (7条数据)
# 已处理 SUI-Boxing (9条数据)
# 已处理 SUI-Canoeing (15条数据)
# 已处理 SUI-Cycling (21条数据)
# 已处理 SUI-Diving (13条数据)
# 已处理 SUI-Equestrianism (20条数据)
# 已处理 SUI-Fencing (24条数据)
# 已处理 SUI-Football (3条数据)
# 已处理 SUI-Golf (3条数据)
# 已处理 SUI-Gymnastics (23条数据)
# 已处理 SUI-Handball (4条数据)
# 已处理 SUI-Hockey (5条数据)
# 已处理 SUI-Judo (15条数据)
# 已处理 SUI-Modern Pentathlon (15条数据)
# 已处理 SUI-Rowing (23条数据)
# 已处理 SUI-Sailing (23条数据)
# 已处理 SUI-Shooting (23条数据)
# 已处理 SUI-Swimming (23条数据)
# 已处理 SUI-Synchronized Swimming (8条数据)
# 已处理 SUI-Tennis (12条数据)
# 已处理 SUI-Triathlon (7条数据)
# 已处理 SUI-Water Polo (5条数据)
# 已处理 SUI-Weightlifting (11条数据)
# 已处理 SUI-Wrestling (21条数据)
# 已处理 SUR-Athletics (13条数据)
# 已处理 SUR-Badminton (5条数据)
# 已处理 SUR-Judo (5条数据)
# 已处理 SUR-Swimming (11条数据)
# 已处理 SVK-Archery (3条数据)
# 已处理 SVK-Athletics (8条数据)
# 已处理 SVK-Badminton (3条数据)
# 已处理 SVK-Boxing (3条数据)
# 已处理 SVK-Canoeing (6条数据)
# 已处理 SVK-Cycling (6条数据)
# 已处理 SVK-Gymnastics (6条数据)
# 已处理 SVK-Judo (6条数据)
# 已处理 SVK-Rowing (3条数据)
# 已处理 SVK-Sailing (5条数据)
# 已处理 SVK-Shooting (8条数据)
# 已处理 SVK-Swimming (8条数据)
# 已处理 SVK-Synchronized Swimming (3条数据)
# 已处理 SVK-Table Tennis (5条数据)
# 已处理 SVK-Tennis (8条数据)
# 已处理 SVK-Triathlon (3条数据)
# 已处理 SVK-Weightlifting (6条数据)
# 已处理 SVK-Wrestling (6条数据)
# 已处理 SWE-Archery (13条数据)
# 已处理 SWE-Art Competitions (3条数据)
# 已处理 SWE-Athletics (30条数据)
# 已处理 SWE-Badminton (8条数据)
# 已处理 SWE-Beach Volleyball (4条数据)
# 已处理 SWE-Boxing (22条数据)
# 已处理 SWE-Canoeing (19条数据)
# 已处理 SWE-Cycling (26条数据)
# 已处理 SWE-Diving (27条数据)
# 已处理 SWE-Equestrianism (22条数据)
# 已处理 SWE-Fencing (24条数据)
# 已处理 SWE-Football (16条数据)
# 已处理 SWE-Golf (3条数据)
# 已处理 SWE-Gymnastics (18条数据)
# 已处理 SWE-Handball (11条数据)
# 已处理 SWE-Judo (13条数据)
# 已处理 SWE-Modern Pentathlon (22条数据)
# 已处理 SWE-Rowing (20条数据)
# 已处理 SWE-Sailing (27条数据)
# 已处理 SWE-Shooting (27条数据)
# 已处理 SWE-Swimming (29条数据)
# 已处理 SWE-Table Tennis (10条数据)
# 已处理 SWE-Taekwondo (4条数据)
# 已处理 SWE-Tennis (13条数据)
# 已处理 SWE-Triathlon (5条数据)
# 已处理 SWE-Tug-Of-War (4条数据)
# 已处理 SWE-Water Polo (8条数据)
# 已处理 SWE-Weightlifting (20条数据)
# 已处理 SWE-Wrestling (27条数据)
# 已处理 SWZ-Athletics (12条数据)
# 已处理 SWZ-Boxing (6条数据)
# 已处理 SWZ-Swimming (9条数据)
# 已处理 SYR-Athletics (12条数据)
# 已处理 SYR-Boxing (7条数据)
# 已处理 SYR-Judo (4条数据)
# 已处理 SYR-Shooting (8条数据)
# 已处理 SYR-Swimming (9条数据)
# 已处理 SYR-Weightlifting (9条数据)
# 已处理 SYR-Wrestling (7条数据)
# 已处理 TAN-Athletics (15条数据)
# 已处理 TAN-Boxing (8条数据)
# 已处理 TAN-Swimming (4条数据)
# 已处理 TCH-Art Competitions (4条数据)
# 已处理 TCH-Athletics (16条数据)
# 已处理 TCH-Basketball (9条数据)
# 已处理 TCH-Boxing (12条数据)
# 已处理 TCH-Canoeing (12条数据)
# 已处理 TCH-Cycling (14条数据)
# 已处理 TCH-Diving (9条数据)
# 已处理 TCH-Equestrianism (5条数据)
# 已处理 TCH-Fencing (9条数据)
# 已处理 TCH-Football (5条数据)
# 已处理 TCH-Gymnastics (15条数据)
# 已处理 TCH-Handball (5条数据)
# 已处理 TCH-Judo (5条数据)
# 已处理 TCH-Modern Pentathlon (9条数据)
# 已处理 TCH-Rowing (14条数据)
# 已处理 TCH-Sailing (7条数据)
# 已处理 TCH-Shooting (13条数据)
# 已处理 TCH-Swimming (15条数据)
# 已处理 TCH-Tennis (4条数据)
# 已处理 TCH-Volleyball (5条数据)
# 已处理 TCH-Water Polo (5条数据)
# 已处理 TCH-Weightlifting (15条数据)
# 已处理 TCH-Wrestling (15条数据)
# 已处理 TGA-Athletics (10条数据)
# 已处理 TGA-Boxing (5条数据)
# 已处理 TGA-Swimming (4条数据)
# 已处理 TGA-Weightlifting (5条数据)
# 已处理 THA-Archery (4条数据)
# 已处理 THA-Athletics (17条数据)
# 已处理 THA-Badminton (9条数据)
# 已处理 THA-Boxing (17条数据)
# 已处理 THA-Cycling (7条数据)
# 已处理 THA-Diving (3条数据)
# 已处理 THA-Fencing (3条数据)
# 已处理 THA-Golf (3条数据)
# 已处理 THA-Judo (9条数据)
# 已处理 THA-Rowing (6条数据)
# 已处理 THA-Sailing (17条数据)
# 已处理 THA-Shooting (16条数据)
# 已处理 THA-Swimming (11条数据)
# 已处理 THA-Table Tennis (7条数据)
# 已处理 THA-Taekwondo (6条数据)
# 已处理 THA-Tennis (6条数据)
# 已处理 THA-Weightlifting (12条数据)
# 已处理 TJK-Athletics (8条数据)
# 已处理 TJK-Boxing (7条数据)
# 已处理 TJK-Judo (6条数据)
# 已处理 TJK-Shooting (3条数据)
# 已处理 TJK-Swimming (6条数据)
# 已处理 TJK-Wrestling (5条数据)
# 已处理 TKM-Athletics (8条数据)
# 已处理 TKM-Boxing (5条数据)
# 已处理 TKM-Judo (8条数据)
# 已处理 TKM-Shooting (4条数据)
# 已处理 TKM-Swimming (6条数据)
# 已处理 TKM-Weightlifting (7条数据)
# 已处理 TLS-Athletics (6条数据)
# 已处理 TOG-Athletics (12条数据)
# 已处理 TOG-Boxing (3条数据)
# 已处理 TOG-Canoeing (3条数据)
# 已处理 TOG-Judo (3条数据)
# 已处理 TOG-Rowing (3条数据)
# 已处理 TOG-Swimming (4条数据)
# 已处理 TPE-Archery (12条数据)
# 已处理 TPE-Athletics (16条数据)
# 已处理 TPE-Badminton (8条数据)
# 已处理 TPE-Baseball (3条数据)
# 已处理 TPE-Boxing (11条数据)
# 已处理 TPE-Cycling (12条数据)
# 已处理 TPE-Fencing (4条数据)
# 已处理 TPE-Golf (3条数据)
# 已处理 TPE-Gymnastics (5条数据)
# 已处理 TPE-Judo (13条数据)
# 已处理 TPE-Rowing (5条数据)
# 已处理 TPE-Sailing (8条数据)
# 已处理 TPE-Shooting (16条数据)
# 已处理 TPE-Softball (3条数据)
# 已处理 TPE-Swimming (13条数据)
# 已处理 TPE-Table Tennis (9条数据)
# 已处理 TPE-Taekwondo (7条数据)
# 已处理 TPE-Tennis (8条数据)
# 已处理 TPE-Weightlifting (16条数据)
# 已处理 TPE-Wrestling (4条数据)
# 已处理 TTO-Athletics (18条数据)
# 已处理 TTO-Boxing (5条数据)
# 已处理 TTO-Cycling (12条数据)
# 已处理 TTO-Sailing (6条数据)
# 已处理 TTO-Shooting (5条数据)
# 已处理 TTO-Swimming (12条数据)
# 已处理 TTO-Weightlifting (5条数据)
# 已处理 TUN-Athletics (15条数据)
# 已处理 TUN-Boxing (15条数据)
# 已处理 TUN-Cycling (3条数据)
# 已处理 TUN-Fencing (9条数据)
# 已处理 TUN-Football (4条数据)
# 已处理 TUN-Handball (5条数据)
# 已处理 TUN-Judo (11条数据)
# 已处理 TUN-Rowing (6条数据)
# 已处理 TUN-Sailing (5条数据)
# 已处理 TUN-Shooting (5条数据)
# 已处理 TUN-Swimming (10条数据)
# 已处理 TUN-Table Tennis (7条数据)
# 已处理 TUN-Taekwondo (6条数据)
# 已处理 TUN-Tennis (6条数据)
# 已处理 TUN-Volleyball (7条数据)
# 已处理 TUN-Weightlifting (9条数据)
# 已处理 TUN-Wrestling (11条数据)
# 已处理 TUR-Archery (11条数据)
# 已处理 TUR-Athletics (22条数据)
# 已处理 TUR-Badminton (4条数据)
# 已处理 TUR-Basketball (4条数据)
# 已处理 TUR-Boxing (14条数据)
# 已处理 TUR-Cycling (8条数据)
# 已处理 TUR-Equestrianism (5条数据)
# 已处理 TUR-Fencing (9条数据)
# 已处理 TUR-Football (6条数据)
# 已处理 TUR-Judo (12条数据)
# 已处理 TUR-Modern Pentathlon (3条数据)
# 已处理 TUR-Rowing (4条数据)
# 已处理 TUR-Sailing (14条数据)
# 已处理 TUR-Shooting (14条数据)
# 已处理 TUR-Swimming (13条数据)
# 已处理 TUR-Table Tennis (4条数据)
# 已处理 TUR-Taekwondo (7条数据)
# 已处理 TUR-Volleyball (3条数据)
# 已处理 TUR-Weightlifting (16条数据)
# 已处理 TUR-Wrestling (22条数据)
# 已处理 TUV-Athletics (5条数据)
# 已处理 UAE-Athletics (10条数据)
# 已处理 UAE-Cycling (4条数据)
# 已处理 UAE-Judo (5条数据)
# 已处理 UAE-Shooting (7条数据)
# 已处理 UAE-Swimming (10条数据)
# 已处理 UGA-Athletics (17条数据)
# 已处理 UGA-Boxing (14条数据)
# 已处理 UGA-Swimming (8条数据)
# 已处理 UGA-Table Tennis (3条数据)
# 已处理 UGA-Weightlifting (5条数据)
# 已处理 UKR-Archery (8条数据)
# 已处理 UKR-Athletics (8条数据)
# 已处理 UKR-Badminton (7条数据)
# 已处理 UKR-Boxing (8条数据)
# 已处理 UKR-Canoeing (6条数据)
# 已处理 UKR-Cycling (6条数据)
# 已处理 UKR-Diving (8条数据)
# 已处理 UKR-Equestrianism (3条数据)
# 已处理 UKR-Fencing (8条数据)
# 已处理 UKR-Gymnastics (6条数据)
# 已处理 UKR-Judo (8条数据)
# 已处理 UKR-Modern Pentathlon (8条数据)
# 已处理 UKR-Rhythmic Gymnastics (8条数据)
# 已处理 UKR-Rowing (8条数据)
# 已处理 UKR-Sailing (6条数据)
# 已处理 UKR-Shooting (8条数据)
# 已处理 UKR-Swimming (8条数据)
# 已处理 UKR-Synchronized Swimming (5条数据)
# 已处理 UKR-Table Tennis (6条数据)
# 已处理 UKR-Tennis (7条数据)
# 已处理 UKR-Trampolining (5条数据)
# 已处理 UKR-Triathlon (6条数据)
# 已处理 UKR-Weightlifting (8条数据)
# 已处理 UKR-Wrestling (8条数据)
# 已处理 URS-Archery (4条数据)
# 已处理 URS-Athletics (9条数据)
# 已处理 URS-Basketball (9条数据)
# 已处理 URS-Boxing (9条数据)
# 已处理 URS-Canoeing (9条数据)
# 已处理 URS-Cycling (9条数据)
# 已处理 URS-Diving (9条数据)
# 已处理 URS-Equestrianism (9条数据)
# 已处理 URS-Fencing (9条数据)
# 已处理 URS-Football (6条数据)
# 已处理 URS-Gymnastics (9条数据)
# 已处理 URS-Handball (4条数据)
# 已处理 URS-Judo (5条数据)
# 已处理 URS-Modern Pentathlon (9条数据)
# 已处理 URS-Rowing (9条数据)
# 已处理 URS-Sailing (9条数据)
# 已处理 URS-Shooting (9条数据)
# 已处理 URS-Swimming (9条数据)
# 已处理 URS-Volleyball (6条数据)
# 已处理 URS-Water Polo (9条数据)
# 已处理 URS-Weightlifting (9条数据)
# 已处理 URS-Wrestling (9条数据)
# 已处理 URU-Art Competitions (3条数据)
# 已处理 URU-Athletics (17条数据)
# 已处理 URU-Basketball (7条数据)
# 已处理 URU-Boxing (12条数据)
# 已处理 URU-Cycling (16条数据)
# 已处理 URU-Equestrianism (3条数据)
# 已处理 URU-Fencing (7条数据)
# 已处理 URU-Football (3条数据)
# 已处理 URU-Judo (7条数据)
# 已处理 URU-Modern Pentathlon (4条数据)
# 已处理 URU-Rowing (18条数据)
# 已处理 URU-Sailing (16条数据)
# 已处理 URU-Shooting (5条数据)
# 已处理 URU-Swimming (16条数据)
# 已处理 URU-Weightlifting (4条数据)
# 已处理 USA-Archery (15条数据)
# 已处理 USA-Art Competitions (5条数据)
# 已处理 USA-Athletics (30条数据)
# 已处理 USA-Badminton (9条数据)
# 已处理 USA-Baseball (4条数据)
# 已处理 USA-Basketball (20条数据)
# 已处理 USA-Beach Volleyball (8条数据)
# 已处理 USA-Boxing (25条数据)
# 已处理 USA-Canoeing (18条数据)
# 已处理 USA-Cycling (26条数据)
# 已处理 USA-Diving (28条数据)
# 已处理 USA-Equestrianism (23条数据)
# 已处理 USA-Fencing (27条数据)
# 已处理 USA-Football (19条数据)
# 已处理 USA-Golf (5条数据)
# 已处理 USA-Gymnastics (23条数据)
# 已处理 USA-Handball (7条数据)
# 已处理 USA-Hockey (11条数据)
# 已处理 USA-Judo (14条数据)
# 已处理 USA-Modern Pentathlon (25条数据)
# 已处理 USA-Polo (3条数据)
# 已处理 USA-Rhythmic Gymnastics (9条数据)
# 已处理 USA-Rowing (26条数据)
# 已处理 USA-Rugby (3条数据)
# 已处理 USA-Rugby Sevens (3条数据)
# 已处理 USA-Sailing (23条数据)
# 已处理 USA-Shooting (26条数据)
# 已处理 USA-Softball (4条数据)
# 已处理 USA-Swimming (30条数据)
# 已处理 USA-Synchronized Swimming (9条数据)
# 已处理 USA-Table Tennis (10条数据)
# 已处理 USA-Taekwondo (7条数据)
# 已处理 USA-Tennis (15条数据)
# 已处理 USA-Trampolining (5条数据)
# 已处理 USA-Triathlon (7条数据)
# 已处理 USA-Tug-Of-War (3条数据)
# 已处理 USA-Volleyball (13条数据)
# 已处理 USA-Water Polo (24条数据)
# 已处理 USA-Weightlifting (22条数据)
# 已处理 USA-Wrestling (28条数据)
# 已处理 UZB-Athletics (8条数据)
# 已处理 UZB-Boxing (8条数据)
# 已处理 UZB-Canoeing (6条数据)
# 已处理 UZB-Cycling (4条数据)
# 已处理 UZB-Fencing (5条数据)
# 已处理 UZB-Gymnastics (5条数据)
# 已处理 UZB-Judo (8条数据)
# 已处理 UZB-Rhythmic Gymnastics (4条数据)
# 已处理 UZB-Rowing (5条数据)
# 已处理 UZB-Shooting (7条数据)
# 已处理 UZB-Swimming (8条数据)
# 已处理 UZB-Taekwondo (6条数据)
# 已处理 UZB-Tennis (6条数据)
# 已处理 UZB-Trampolining (5条数据)
# 已处理 UZB-Weightlifting (8条数据)
# 已处理 UZB-Wrestling (8条数据)
# 已处理 VAN-Athletics (8条数据)
# 已处理 VAN-Judo (4条数据)
# 已处理 VAN-Table Tennis (5条数据)
# 已处理 VEN-Archery (3条数据)
# 已处理 VEN-Athletics (17条数据)
# 已处理 VEN-Boxing (18条数据)
# 已处理 VEN-Cycling (15条数据)
# 已处理 VEN-Diving (11条数据)
# 已处理 VEN-Equestrianism (4条数据)
# 已处理 VEN-Fencing (12条数据)
# 已处理 VEN-Gymnastics (4条数据)
# 已处理 VEN-Judo (13条数据)
# 已处理 VEN-Rowing (3条数据)
# 已处理 VEN-Sailing (11条数据)
# 已处理 VEN-Shooting (15条数据)
# 已处理 VEN-Swimming (15条数据)
# 已处理 VEN-Synchronized Swimming (4条数据)
# 已处理 VEN-Table Tennis (7条数据)
# 已处理 VEN-Taekwondo (5条数据)
# 已处理 VEN-Tennis (4条数据)
# 已处理 VEN-Weightlifting (12条数据)
# 已处理 VEN-Wrestling (10条数据)
# 已处理 VIE-Athletics (11条数据)
# 已处理 VIE-Badminton (5条数据)
# 已处理 VIE-Boxing (3条数据)
# 已处理 VIE-Gymnastics (3条数据)
# 已处理 VIE-Judo (5条数据)
# 已处理 VIE-Rowing (5条数据)
# 已处理 VIE-Shooting (11条数据)
# 已处理 VIE-Swimming (11条数据)
# 已处理 VIE-Taekwondo (5条数据)
# 已处理 VIE-Weightlifting (6条数据)
# 已处理 VIE-Wrestling (4条数据)
# 已处理 VIN-Athletics (10条数据)
# 已处理 VIN-Swimming (6条数据)
# 已处理 VNM-Athletics (3条数据)
# 已处理 VNM-Cycling (4条数据)
# 已处理 VNM-Fencing (4条数据)
# 已处理 VNM-Swimming (4条数据)
# 已处理 YEM-Athletics (9条数据)
# 已处理 YEM-Judo (6条数据)
# 已处理 YEM-Swimming (5条数据)
# 已处理 YUG-Art Competitions (3条数据)
# 已处理 YUG-Athletics (15条数据)
# 已处理 YUG-Basketball (8条数据)
# 已处理 YUG-Boxing (8条数据)
# 已处理 YUG-Canoeing (10条数据)
# 已处理 YUG-Cycling (12条数据)
# 已处理 YUG-Fencing (3条数据)
# 已处理 YUG-Football (11条数据)
# 已处理 YUG-Gymnastics (10条数据)
# 已处理 YUG-Handball (5条数据)
# 已处理 YUG-Judo (5条数据)
# 已处理 YUG-Rowing (11条数据)
# 已处理 YUG-Sailing (9条数据)
# 已处理 YUG-Shooting (10条数据)
# 已处理 YUG-Swimming (13条数据)
# 已处理 YUG-Water Polo (12条数据)
# 已处理 YUG-Wrestling (13条数据)
# 已处理 ZAM-Athletics (15条数据)
# 已处理 ZAM-Boxing (15条数据)
# 已处理 ZAM-Football (4条数据)
# 已处理 ZAM-Judo (7条数据)
# 已处理 ZAM-Swimming (8条数据)
# 已处理 ZIM-Archery (3条数据)
# 已处理 ZIM-Athletics (13条数据)
# 已处理 ZIM-Boxing (5条数据)
# 已处理 ZIM-Cycling (4条数据)
# 已处理 ZIM-Diving (7条数据)
# 已处理 ZIM-Judo (3条数据)
# 已处理 ZIM-Rowing (6条数据)
# 已处理 ZIM-Sailing (4条数据)
# 已处理 ZIM-Shooting (6条数据)
# 已处理 ZIM-Swimming (13条数据)
# 已处理 ZIM-Tennis (6条数据)
# 已处理 ZIM-Triathlon (3条数据)
# 处理完成！共处理22985条有效记录

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import MultipleLocator
from matplotlib.lines import Line2D

# 可视化配置
sns.set_theme(style="darkgrid")
COUNTRIES = ['USA', 'CHN']  # 只保留中美两国

def plot_decomposition_trends(result_df):
    """绘制中美趋势分解图（英文版）"""
    # 配置绘图参数
    plt.rcParams.update({
        'font.sans-serif': ['Arial'],  # 使用英文字体
        'axes.unicode_minus': False,
        'figure.figsize': (12, 6),
        'savefig.dpi': 300
    })

    # 数据预处理
    target_df = result_df[
        (result_df['NOC'].isin(COUNTRIES)) &
        (result_df['Year'] >= 2000)
    ].copy()
    target_df['Year'] = target_df['Year'].astype(int)
    target_df = target_df.sort_values('Year')

    # 创建画布
    fig, ax = plt.subplots()
    
    # 定义可视化元素
    components = ['Total', 'Trend', 'Seasonal']
    line_styles = ['-', '--', '-.']
    colors = sns.color_palette("husl", n_colors=2)
    
    # 绘制趋势线
    for country_idx, country in enumerate(COUNTRIES):
        country_data = target_df[target_df['NOC'] == country]
        
        for comp_idx, comp in enumerate(components):
            ax.plot(
                country_data['Year'],
                country_data[comp],
                label=f'{country} {comp}',
                linestyle=line_styles[comp_idx],
                color=colors[country_idx],
                alpha=0.8,
                linewidth=2 if comp == 'Total' else 1.5
            )

    # 坐标轴设置
    ax.set_xlim(2000, 2020)
    ax.set_ylim(0, target_df['Total'].max()*1.1)
    ax.xaxis.set_major_locator(MultipleLocator(4))
    ax.set_xlabel('Olympic Year', fontsize=12)
    ax.set_ylabel('Medal Count / Components', fontsize=12)
    ax.set_title('China vs USA Olympic Medal Trend Analysis (2000-2020)', 
                pad=15, fontsize=14, fontweight='bold')

    # 优化图例
    handles, labels = ax.get_legend_handles_labels()
    
    # 成分图例（线型）
    comp_legend = plt.legend(
        handles[:3],
        ['Total Medals', 'Long-term Trend', 'Olympic Cycle Effect'],
        title='Components',
        loc='upper left',
        frameon=True,
        shadow=True
    )
    
    # 国家图例（颜色）
    country_legend = plt.legend(
        [Line2D([0], [0], color=colors[i], lw=2) for i in range(2)],
        COUNTRIES,
        title='Countries',
        loc='lower right',
        frameon=True,
        shadow=True
    )
    
    ax.add_artist(comp_legend)
    ax.add_artist(country_legend)

    # 输出图像
    output_path = r"C:\Users\NANA\.jupyter\JupyterProject\MCM_02\china_usa_comparison_en.png"
    plt.savefig(output_path, bbox_inches='tight')
    print(f'Visualization saved to: {output_path}')
    plt.close()

def main():
    # 读取数据并过滤
    result_df = pd.read_csv(r"C:\Users\NANA\.jupyter\JupyterProject\MCM_02\code\data\decomposition_results.csv")
    result_df = result_df[result_df['Year'] >= 2000]
    
    # 执行可视化
    plot_decomposition_trends(result_df)

if __name__ == '__main__':
    main()
# Out:
# Visualization saved to: C:\Users\NANA\.jupyter\JupyterProject\MCM_02\china_usa_comparison_en.png
